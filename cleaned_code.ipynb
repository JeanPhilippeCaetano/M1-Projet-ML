# %%
import os
from PIL import Image
import numpy as np
import pandas as pd
import xml.etree.ElementTree as ET  # Pour parser les fichiers XML
import cv2
from ultralytics import YOLO

from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, f1_score
from sklearn.preprocessing import LabelEncoder

import pickle
from sklearn.model_selection import SelectFromModel
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## Data Prep

# %%
def extract_color_histogram(image, bins=(8, 8, 8)):
    # Convertir l'image en espace de couleur HSV
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    
    # Calculer l'histogramme en 3D pour H, S et V
    hist = cv2.calcHist([hsv], [0, 1, 2], None, bins, [0, 180, 0, 256, 0, 256])
    
    # Normaliser l'histogramme
    cv2.normalize(hist, hist)
    
    return hist.flatten()

# %%
def extract_shape_features(image):
    # Convertir en niveaux de gris
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Seuillage pour obtenir un contour net
    _, thresh = cv2.threshold(gray, 128, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)
    
    # Trouver les contours
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Si des contours existent, calculer les moments de Hu
    if contours:
        cnt = max(contours, key=cv2.contourArea)  # Prendre le plus grand contour
        moments = cv2.moments(cnt)
        hu_moments = cv2.HuMoments(moments).flatten()
        
        # Normalisation log
        hu_moments = -np.sign(hu_moments) * np.log10(np.abs(hu_moments) + 1e-10)
        
        return hu_moments
    return None

# %%
def extract_hog_features(image):
    # Convertir en niveaux de gris
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Vérifier que l'image n'est pas vide
    if gray is None or gray.size == 0:
        print("Erreur : Image vide pour HOG")
        return np.array([])  # Retourne un tableau vide si problème

    # Redimensionner l'image à une taille standard (64x128 pour HOG)
    gray = cv2.resize(gray, (64, 128))

    # Définir le descripteur HOG
    hog = cv2.HOGDescriptor()

    # Calculer les descripteurs HOG
    hog_features = hog.compute(gray)

    # Vérifier si le calcul est réussi
    if hog_features is None:
        print("Erreur : Impossible de calculer HOG")
        return np.array([])

    return hog_features.flatten()

# %%
# Charger le modèle YOLO
model = YOLO("yolov8n.pt")

# Dossiers
dossier_origin = "train/"
output_folder = "detected_objects"

# Vérifier et créer le dossier de sortie
os.makedirs(output_folder, exist_ok=True)

# Parcourir toutes les images dans le dossier d'origine
for k, nom_fichier in enumerate(os.listdir(dossier_origin)):
    if nom_fichier.endswith(".jpg"): 
        image_path = os.path.join(dossier_origin, nom_fichier)
        image = cv2.imread(image_path)  # Charger l'image

        if image is None:
            print(f"Erreur : Impossible de charger {image_path}")
            continue

        # Faire la détection sur cette image
        results = model(image)

        # Extraire les objets détectés
        for i, (box, cls) in enumerate(zip(results[0].boxes.xyxy, results[0].boxes.cls)):
            x_min, y_min, x_max, y_max = map(int, box)  # Convertir en entiers
            class_name = model.names[int(cls)]  # Obtenir le nom de la classe détectée

            # Rogner l'objet détecté
            cropped_object = image[y_min:y_max, x_min:x_max]

            # Vérifier si le crop est valide
            if cropped_object.shape[0] == 0 or cropped_object.shape[1] == 0:
                print(f"Avertissement : Objet {class_name} ignoré (zone trop petite)")
                continue

            # Construire le chemin du fichier avec le nom de l'image d'origine
            if class_name in {"banana", "apple", "orange"}:
                filename = os.path.join(output_folder, f"{class_name}_{k}_{i}.jpg")

                # Sauvegarder l'image découpée
                cv2.imwrite(filename, cropped_object)
                print(f"Objet détecté enregistré : {filename}")

print("Extraction terminée.")
# Out:
# 0: 640x640 1 apple, 160.8ms
# Speed: 13.1ms preprocess, 160.8ms inference, 10.9ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_0_0.jpg
#
# 0: 640x640 1 apple, 102.8ms
# Speed: 6.4ms preprocess, 102.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_2_0.jpg
#
# 0: 448x640 3 apples, 1 carrot, 107.2ms
# Speed: 4.2ms preprocess, 107.2ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_4_0.jpg
# Objet détecté enregistré : detected_objects\apple_4_1.jpg
# Objet détecté enregistré : detected_objects\apple_4_2.jpg
#
# 0: 640x640 2 apples, 82.6ms
# Speed: 4.1ms preprocess, 82.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_6_0.jpg
# Objet détecté enregistré : detected_objects\apple_6_1.jpg
#
# 0: 640x640 3 apples, 89.2ms
# Speed: 4.4ms preprocess, 89.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_8_0.jpg
# Objet détecté enregistré : detected_objects\apple_8_1.jpg
# Objet détecté enregistré : detected_objects\apple_8_2.jpg
#
# 0: 448x640 2 apples, 1 orange, 80.1ms
# Speed: 2.7ms preprocess, 80.1ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\orange_10_0.jpg
# Objet détecté enregistré : detected_objects\apple_10_1.jpg
# Objet détecté enregistré : detected_objects\apple_10_2.jpg
#
# 0: 480x640 1 apple, 145.5ms
# Speed: 3.0ms preprocess, 145.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_12_0.jpg
#
# 0: 608x640 1 apple, 105.8ms
# Speed: 5.2ms preprocess, 105.8ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
# Objet détecté enregistré : detected_objects\apple_14_0.jpg
#
# 0: 640x576 1 apple, 108.2ms
# Speed: 3.9ms preprocess, 108.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
# Objet détecté enregistré : detected_objects\apple_16_0.jpg
#
# 0: 512x640 (no detections), 114.2ms
# Speed: 3.8ms preprocess, 114.2ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 480x640 1 apple, 86.5ms
# Speed: 4.1ms preprocess, 86.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_20_0.jpg
#
# 0: 640x640 1 apple, 87.4ms
# Speed: 4.0ms preprocess, 87.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_22_0.jpg
#
# 0: 640x640 1 stop sign, 1 umbrella, 81.1ms
# Speed: 6.1ms preprocess, 81.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 448x640 2 apples, 64.9ms
# Speed: 2.3ms preprocess, 64.9ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_26_0.jpg
# Objet détecté enregistré : detected_objects\apple_26_1.jpg
#
# 0: 640x640 1 apple, 80.8ms
# Speed: 4.5ms preprocess, 80.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_28_0.jpg
#
# 0: 640x640 3 apples, 81.5ms
# Speed: 5.0ms preprocess, 81.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_30_0.jpg
# Objet détecté enregistré : detected_objects\apple_30_1.jpg
# Objet détecté enregistré : detected_objects\apple_30_2.jpg
#
# 0: 640x448 1 bowl, 4 apples, 1 dining table, 82.7ms
# Speed: 3.0ms preprocess, 82.7ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 448)
# Objet détecté enregistré : detected_objects\apple_32_1.jpg
# Objet détecté enregistré : detected_objects\apple_32_2.jpg
# Objet détecté enregistré : detected_objects\apple_32_3.jpg
# Objet détecté enregistré : detected_objects\apple_32_5.jpg
#
# 0: 448x640 2 apples, 55.4ms
# Speed: 2.8ms preprocess, 55.4ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_34_0.jpg
# Objet détecté enregistré : detected_objects\apple_34_1.jpg
#
# 0: 448x640 2 apples, 63.8ms
# Speed: 1.7ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_36_0.jpg
# Objet détecté enregistré : detected_objects\apple_36_1.jpg
#
# 0: 320x640 3 apples, 91.4ms
# Speed: 1.8ms preprocess, 91.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# Objet détecté enregistré : detected_objects\apple_38_0.jpg
# Objet détecté enregistré : detected_objects\apple_38_1.jpg
# Objet détecté enregistré : detected_objects\apple_38_2.jpg
#
# 0: 640x640 1 apple, 125.3ms
# Speed: 5.3ms preprocess, 125.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_40_0.jpg
#
# 0: 640x640 1 apple, 77.6ms
# Speed: 4.1ms preprocess, 77.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_42_0.jpg
#
# 0: 480x640 17 apples, 121.5ms
# Speed: 3.4ms preprocess, 121.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_44_0.jpg
# Objet détecté enregistré : detected_objects\apple_44_1.jpg
# Objet détecté enregistré : detected_objects\apple_44_2.jpg
# Objet détecté enregistré : detected_objects\apple_44_3.jpg
# Objet détecté enregistré : detected_objects\apple_44_4.jpg
# Objet détecté enregistré : detected_objects\apple_44_5.jpg
# Objet détecté enregistré : detected_objects\apple_44_6.jpg
# Objet détecté enregistré : detected_objects\apple_44_7.jpg
# Objet détecté enregistré : detected_objects\apple_44_8.jpg
# Objet détecté enregistré : detected_objects\apple_44_9.jpg
# Objet détecté enregistré : detected_objects\apple_44_10.jpg
# Objet détecté enregistré : detected_objects\apple_44_11.jpg
# Objet détecté enregistré : detected_objects\apple_44_12.jpg
# Objet détecté enregistré : detected_objects\apple_44_13.jpg
# Objet détecté enregistré : detected_objects\apple_44_14.jpg
# Objet détecté enregistré : detected_objects\apple_44_15.jpg
# Objet détecté enregistré : detected_objects\apple_44_16.jpg
#
# 0: 640x640 4 apples, 79.4ms
# Speed: 4.9ms preprocess, 79.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_46_0.jpg
# Objet détecté enregistré : detected_objects\apple_46_1.jpg
# Objet détecté enregistré : detected_objects\apple_46_2.jpg
# Objet détecté enregistré : detected_objects\apple_46_3.jpg
#
# 0: 384x640 3 apples, 1 orange, 124.6ms
# Speed: 2.5ms preprocess, 124.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\apple_48_0.jpg
# Objet détecté enregistré : detected_objects\apple_48_1.jpg
# Objet détecté enregistré : detected_objects\orange_48_2.jpg
# Objet détecté enregistré : detected_objects\apple_48_3.jpg
#
# 0: 480x640 2 apples, 124.4ms
# Speed: 9.8ms preprocess, 124.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_50_0.jpg
# Objet détecté enregistré : detected_objects\apple_50_1.jpg
#
# 0: 640x640 1 apple, 91.9ms
# Speed: 5.2ms preprocess, 91.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_52_0.jpg
#
# 0: 640x448 1 apple, 61.6ms
# Speed: 2.2ms preprocess, 61.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
# Objet détecté enregistré : detected_objects\apple_54_0.jpg
#
# 0: 640x640 (no detections), 79.4ms
# Speed: 4.3ms preprocess, 79.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 608x640 1 apple, 76.5ms
# Speed: 5.4ms preprocess, 76.5ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 640)
# Objet détecté enregistré : detected_objects\apple_58_0.jpg
#
# 0: 640x608 1 kite, 1 apple, 2 oranges, 136.9ms
# Speed: 6.4ms preprocess, 136.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 608)
# Objet détecté enregistré : detected_objects\orange_60_0.jpg
# Objet détecté enregistré : detected_objects\apple_60_1.jpg
# Objet détecté enregistré : detected_objects\orange_60_3.jpg
#
# 0: 384x640 1 apple, 61.0ms
# Speed: 3.5ms preprocess, 61.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\apple_62_0.jpg
#
# 0: 448x640 2 apples, 58.6ms
# Speed: 2.3ms preprocess, 58.6ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_64_0.jpg
# Objet détecté enregistré : detected_objects\apple_64_1.jpg
#
# 0: 416x640 2 apples, 2 oranges, 81.3ms
# Speed: 2.4ms preprocess, 81.3ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
# Objet détecté enregistré : detected_objects\orange_66_0.jpg
# Objet détecté enregistré : detected_objects\apple_66_1.jpg
# Objet détecté enregistré : detected_objects\apple_66_2.jpg
# Objet détecté enregistré : detected_objects\orange_66_3.jpg
#
# 0: 544x640 1 vase, 100.4ms
# Speed: 4.6ms preprocess, 100.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 640x640 1 apple, 80.5ms
# Speed: 6.0ms preprocess, 80.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_70_0.jpg
#
# 0: 640x640 (no detections), 74.2ms
# Speed: 5.8ms preprocess, 74.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 apple, 95.8ms
# Speed: 5.3ms preprocess, 95.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_74_0.jpg
#
# 0: 512x640 2 apples, 1 orange, 86.7ms
# Speed: 2.7ms preprocess, 86.7ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 640)
# Objet détecté enregistré : detected_objects\apple_76_0.jpg
# Objet détecté enregistré : detected_objects\apple_76_1.jpg
# Objet détecté enregistré : detected_objects\orange_76_2.jpg
#
# 0: 480x640 6 apples, 74.6ms
# Speed: 2.4ms preprocess, 74.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_78_0.jpg
# Objet détecté enregistré : detected_objects\apple_78_1.jpg
# Objet détecté enregistré : detected_objects\apple_78_2.jpg
# Objet détecté enregistré : detected_objects\apple_78_3.jpg
# Objet détecté enregistré : detected_objects\apple_78_4.jpg
# Objet détecté enregistré : detected_objects\apple_78_5.jpg
#
# 0: 448x640 4 apples, 74.7ms
# Speed: 2.6ms preprocess, 74.7ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_80_0.jpg
# Objet détecté enregistré : detected_objects\apple_80_1.jpg
# Objet détecté enregistré : detected_objects\apple_80_2.jpg
# Objet détecté enregistré : detected_objects\apple_80_3.jpg
#
# 0: 448x640 2 apples, 83.2ms
# Speed: 2.8ms preprocess, 83.2ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_82_0.jpg
# Objet détecté enregistré : detected_objects\apple_82_1.jpg
#
# 0: 640x608 1 cake, 86.3ms
# Speed: 5.0ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 384x640 8 apples, 61.1ms
# Speed: 2.7ms preprocess, 61.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\apple_86_0.jpg
# Objet détecté enregistré : detected_objects\apple_86_1.jpg
# Objet détecté enregistré : detected_objects\apple_86_2.jpg
# Objet détecté enregistré : detected_objects\apple_86_3.jpg
# Objet détecté enregistré : detected_objects\apple_86_4.jpg
# Objet détecté enregistré : detected_objects\apple_86_5.jpg
# Objet détecté enregistré : detected_objects\apple_86_6.jpg
# Objet détecté enregistré : detected_objects\apple_86_7.jpg
#
# 0: 512x640 4 apples, 92.4ms
# Speed: 2.5ms preprocess, 92.4ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
# Objet détecté enregistré : detected_objects\apple_88_0.jpg
# Objet détecté enregistré : detected_objects\apple_88_1.jpg
# Objet détecté enregistré : detected_objects\apple_88_2.jpg
# Objet détecté enregistré : detected_objects\apple_88_3.jpg
#
# 0: 640x576 1 apple, 91.4ms
# Speed: 5.7ms preprocess, 91.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
# Objet détecté enregistré : detected_objects\apple_90_0.jpg
#
# 0: 640x640 6 apples, 94.4ms
# Speed: 5.8ms preprocess, 94.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_92_0.jpg
# Objet détecté enregistré : detected_objects\apple_92_1.jpg
# Objet détecté enregistré : detected_objects\apple_92_2.jpg
# Objet détecté enregistré : detected_objects\apple_92_3.jpg
# Objet détecté enregistré : detected_objects\apple_92_4.jpg
# Objet détecté enregistré : detected_objects\apple_92_5.jpg
#
# 0: 576x640 1 apple, 98.4ms
# Speed: 4.3ms preprocess, 98.4ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# Objet détecté enregistré : detected_objects\apple_94_0.jpg
#
# 0: 608x640 1 apple, 1 donut, 84.7ms
# Speed: 4.9ms preprocess, 84.7ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
# Objet détecté enregistré : detected_objects\apple_96_0.jpg
#
# 0: 448x640 6 apples, 2 oranges, 73.1ms
# Speed: 2.6ms preprocess, 73.1ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_98_0.jpg
# Objet détecté enregistré : detected_objects\apple_98_1.jpg
# Objet détecté enregistré : detected_objects\apple_98_2.jpg
# Objet détecté enregistré : detected_objects\apple_98_3.jpg
# Objet détecté enregistré : detected_objects\apple_98_4.jpg
# Objet détecté enregistré : detected_objects\apple_98_5.jpg
# Objet détecté enregistré : detected_objects\orange_98_6.jpg
# Objet détecté enregistré : detected_objects\orange_98_7.jpg
#
# 0: 480x640 1 apple, 76.6ms
# Speed: 3.6ms preprocess, 76.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_100_0.jpg
#
# 0: 448x640 1 apple, 85.9ms
# Speed: 2.3ms preprocess, 85.9ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_102_0.jpg
#
# 0: 640x576 4 apples, 84.5ms
# Speed: 4.5ms preprocess, 84.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 576)
# Objet détecté enregistré : detected_objects\apple_104_0.jpg
# Objet détecté enregistré : detected_objects\apple_104_1.jpg
# Objet détecté enregistré : detected_objects\apple_104_2.jpg
# Objet détecté enregistré : detected_objects\apple_104_3.jpg
#
# 0: 480x640 2 apples, 1 orange, 67.5ms
# Speed: 2.8ms preprocess, 67.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_106_0.jpg
# Objet détecté enregistré : detected_objects\apple_106_1.jpg
# Objet détecté enregistré : detected_objects\orange_106_2.jpg
#
# 0: 416x640 3 apples, 1 orange, 60.5ms
# Speed: 2.5ms preprocess, 60.5ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
# Objet détecté enregistré : detected_objects\apple_108_0.jpg
# Objet détecté enregistré : detected_objects\orange_108_1.jpg
# Objet détecté enregistré : detected_objects\apple_108_2.jpg
# Objet détecté enregistré : detected_objects\apple_108_3.jpg
#
# 0: 640x640 8 apples, 78.8ms
# Speed: 6.1ms preprocess, 78.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_110_0.jpg
# Objet détecté enregistré : detected_objects\apple_110_1.jpg
# Objet détecté enregistré : detected_objects\apple_110_2.jpg
# Objet détecté enregistré : detected_objects\apple_110_3.jpg
# Objet détecté enregistré : detected_objects\apple_110_4.jpg
# Objet détecté enregistré : detected_objects\apple_110_5.jpg
# Objet détecté enregistré : detected_objects\apple_110_6.jpg
# Objet détecté enregistré : detected_objects\apple_110_7.jpg
#
# 0: 640x640 2 apples, 1 orange, 75.4ms
# Speed: 4.8ms preprocess, 75.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_112_0.jpg
# Objet détecté enregistré : detected_objects\orange_112_1.jpg
# Objet détecté enregistré : detected_objects\apple_112_2.jpg
#
# 0: 448x640 1 apple, 59.6ms
# Speed: 1.8ms preprocess, 59.6ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_114_0.jpg
#
# 0: 384x640 4 apples, 1 orange, 55.7ms
# Speed: 6.6ms preprocess, 55.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\apple_116_0.jpg
# Objet détecté enregistré : detected_objects\apple_116_1.jpg
# Objet détecté enregistré : detected_objects\apple_116_2.jpg
# Objet détecté enregistré : detected_objects\apple_116_3.jpg
# Objet détecté enregistré : detected_objects\orange_116_4.jpg
#
# 0: 640x640 3 apples, 84.2ms
# Speed: 4.1ms preprocess, 84.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_118_0.jpg
# Objet détecté enregistré : detected_objects\apple_118_1.jpg
# Objet détecté enregistré : detected_objects\apple_118_2.jpg
#
# 0: 480x640 5 apples, 68.2ms
# Speed: 2.2ms preprocess, 68.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_120_0.jpg
# Objet détecté enregistré : detected_objects\apple_120_1.jpg
# Objet détecté enregistré : detected_objects\apple_120_2.jpg
# Objet détecté enregistré : detected_objects\apple_120_3.jpg
# Objet détecté enregistré : detected_objects\apple_120_4.jpg
#
# 0: 480x640 3 apples, 63.1ms
# Speed: 3.3ms preprocess, 63.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_122_0.jpg
# Objet détecté enregistré : detected_objects\apple_122_1.jpg
# Objet détecté enregistré : detected_objects\apple_122_2.jpg
#
# 0: 512x640 3 apples, 72.3ms
# Speed: 2.8ms preprocess, 72.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Objet détecté enregistré : detected_objects\apple_124_0.jpg
# Objet détecté enregistré : detected_objects\apple_124_1.jpg
# Objet détecté enregistré : detected_objects\apple_124_2.jpg
#
# 0: 640x640 2 apples, 80.5ms
# Speed: 4.9ms preprocess, 80.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_126_0.jpg
# Objet détecté enregistré : detected_objects\apple_126_1.jpg
#
# 0: 640x640 3 apples, 80.0ms
# Speed: 4.6ms preprocess, 80.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_128_0.jpg
# Objet détecté enregistré : detected_objects\apple_128_1.jpg
# Objet détecté enregistré : detected_objects\apple_128_2.jpg
#
# 0: 640x640 1 apple, 87.8ms
# Speed: 4.4ms preprocess, 87.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_130_0.jpg
#
# 0: 640x512 1 apple, 116.6ms
# Speed: 2.9ms preprocess, 116.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
# Objet détecté enregistré : detected_objects\apple_132_0.jpg
#
# 0: 384x640 4 apples, 86.2ms
# Speed: 2.1ms preprocess, 86.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\apple_134_0.jpg
# Objet détecté enregistré : detected_objects\apple_134_1.jpg
# Objet détecté enregistré : detected_objects\apple_134_2.jpg
# Objet détecté enregistré : detected_objects\apple_134_3.jpg
#
# 0: 640x640 1 apple, 83.3ms
# Speed: 4.7ms preprocess, 83.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_136_0.jpg
#
# 0: 640x640 1 apple, 81.6ms
# Speed: 3.8ms preprocess, 81.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_138_0.jpg
#
# 0: 640x640 2 apples, 77.0ms
# Speed: 5.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_140_0.jpg
# Objet détecté enregistré : detected_objects\apple_140_1.jpg
#
# 0: 640x640 1 apple, 85.1ms
# Speed: 4.4ms preprocess, 85.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_142_0.jpg
#
# 0: 512x640 2 apples, 84.5ms
# Speed: 3.4ms preprocess, 84.5ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
# Objet détecté enregistré : detected_objects\apple_144_0.jpg
# Objet détecté enregistré : detected_objects\apple_144_1.jpg
#
# 0: 480x640 1 apple, 95.0ms
# Speed: 2.4ms preprocess, 95.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_146_0.jpg
#
# 0: 480x640 1 apple, 71.2ms
# Speed: 2.7ms preprocess, 71.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_148_0.jpg
#
# 0: 384x640 1 banana, 115.3ms
# Speed: 2.2ms preprocess, 115.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_150_0.jpg
#
# 0: 448x640 4 bananas, 67.2ms
# Speed: 3.3ms preprocess, 67.2ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_152_0.jpg
# Objet détecté enregistré : detected_objects\banana_152_1.jpg
# Objet détecté enregistré : detected_objects\banana_152_2.jpg
# Objet détecté enregistré : detected_objects\banana_152_3.jpg
#
# 0: 640x640 1 scissors, 80.5ms
# Speed: 4.4ms preprocess, 80.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 banana, 88.3ms
# Speed: 3.2ms preprocess, 88.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\banana_156_0.jpg
#
# 0: 640x640 1 kite, 84.6ms
# Speed: 5.4ms preprocess, 84.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 512x640 1 bowl, 1 banana, 1 dining table, 72.9ms
# Speed: 2.3ms preprocess, 72.9ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
# Objet détecté enregistré : detected_objects\banana_160_0.jpg
#
# 0: 384x640 1 banana, 1 scissors, 62.0ms
# Speed: 2.4ms preprocess, 62.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_162_1.jpg
#
# 0: 640x640 4 bananas, 85.3ms
# Speed: 3.5ms preprocess, 85.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\banana_164_0.jpg
# Objet détecté enregistré : detected_objects\banana_164_1.jpg
# Objet détecté enregistré : detected_objects\banana_164_2.jpg
# Objet détecté enregistré : detected_objects\banana_164_3.jpg
#
# 0: 544x640 (no detections), 77.1ms
# Speed: 4.6ms preprocess, 77.1ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 banana, 60.7ms
# Speed: 2.6ms preprocess, 60.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_168_0.jpg
#
# 0: 384x640 1 banana, 64.1ms
# Speed: 1.7ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_170_0.jpg
#
# 0: 448x640 4 bananas, 82.9ms
# Speed: 3.0ms preprocess, 82.9ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_172_0.jpg
# Objet détecté enregistré : detected_objects\banana_172_1.jpg
# Objet détecté enregistré : detected_objects\banana_172_2.jpg
# Objet détecté enregistré : detected_objects\banana_172_3.jpg
#
# 0: 352x640 1 banana, 94.5ms
# Speed: 1.9ms preprocess, 94.5ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
# Objet détecté enregistré : detected_objects\banana_174_0.jpg
#
# 0: 352x640 1 banana, 59.9ms
# Speed: 1.3ms preprocess, 59.9ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
# Objet détecté enregistré : detected_objects\banana_176_0.jpg
#
# 0: 640x448 2 bananas, 99.5ms
# Speed: 2.0ms preprocess, 99.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
# Objet détecté enregistré : detected_objects\banana_178_0.jpg
# Objet détecté enregistré : detected_objects\banana_178_1.jpg
#
# 0: 352x640 1 banana, 60.0ms
# Speed: 1.8ms preprocess, 60.0ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
# Objet détecté enregistré : detected_objects\banana_180_0.jpg
#
# 0: 512x640 4 bananas, 65.1ms
# Speed: 2.9ms preprocess, 65.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Objet détecté enregistré : detected_objects\banana_182_0.jpg
# Objet détecté enregistré : detected_objects\banana_182_1.jpg
# Objet détecté enregistré : detected_objects\banana_182_2.jpg
# Objet détecté enregistré : detected_objects\banana_182_3.jpg
#
# 0: 640x640 1 banana, 85.2ms
# Speed: 5.5ms preprocess, 85.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\banana_184_0.jpg
#
# 0: 480x640 1 banana, 80.4ms
# Speed: 2.8ms preprocess, 80.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\banana_186_0.jpg
#
# 0: 448x640 1 banana, 69.5ms
# Speed: 2.3ms preprocess, 69.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_188_0.jpg
#
# 0: 512x640 2 bananas, 71.1ms
# Speed: 2.4ms preprocess, 71.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Objet détecté enregistré : detected_objects\banana_190_0.jpg
# Objet détecté enregistré : detected_objects\banana_190_1.jpg
#
# 0: 384x640 1 banana, 58.2ms
# Speed: 2.0ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_192_0.jpg
#
# 0: 544x640 3 bananas, 75.2ms
# Speed: 3.9ms preprocess, 75.2ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
# Objet détecté enregistré : detected_objects\banana_194_0.jpg
# Objet détecté enregistré : detected_objects\banana_194_1.jpg
# Objet détecté enregistré : detected_objects\banana_194_2.jpg
#
# 0: 480x640 (no detections), 69.1ms
# Speed: 2.4ms preprocess, 69.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x608 2 bananas, 120.9ms
# Speed: 4.7ms preprocess, 120.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 608)
# Objet détecté enregistré : detected_objects\banana_198_0.jpg
# Objet détecté enregistré : detected_objects\banana_198_1.jpg
#
# 0: 448x640 1 banana, 2 apples, 2 oranges, 89.3ms
# Speed: 3.0ms preprocess, 89.3ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_200_0.jpg
# Objet détecté enregistré : detected_objects\banana_200_1.jpg
# Objet détecté enregistré : detected_objects\orange_200_2.jpg
# Objet détecté enregistré : detected_objects\apple_200_3.jpg
# Objet détecté enregistré : detected_objects\orange_200_4.jpg
#
# 0: 416x640 1 banana, 83.0ms
# Speed: 5.1ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# Objet détecté enregistré : detected_objects\banana_202_0.jpg
#
# 0: 384x640 9 bananas, 61.1ms
# Speed: 1.9ms preprocess, 61.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_204_0.jpg
# Objet détecté enregistré : detected_objects\banana_204_1.jpg
# Objet détecté enregistré : detected_objects\banana_204_2.jpg
# Objet détecté enregistré : detected_objects\banana_204_3.jpg
# Objet détecté enregistré : detected_objects\banana_204_4.jpg
# Objet détecté enregistré : detected_objects\banana_204_5.jpg
# Objet détecté enregistré : detected_objects\banana_204_6.jpg
# Objet détecté enregistré : detected_objects\banana_204_7.jpg
# Objet détecté enregistré : detected_objects\banana_204_8.jpg
#
# 0: 544x640 2 bananas, 79.3ms
# Speed: 3.5ms preprocess, 79.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# Objet détecté enregistré : detected_objects\banana_206_0.jpg
# Objet détecté enregistré : detected_objects\banana_206_1.jpg
#
# 0: 640x640 1 banana, 100.1ms
# Speed: 4.6ms preprocess, 100.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\banana_208_0.jpg
#
# 0: 448x640 2 bananas, 1 dining table, 75.6ms
# Speed: 3.2ms preprocess, 75.6ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_210_0.jpg
# Objet détecté enregistré : detected_objects\banana_210_1.jpg
#
# 0: 448x640 1 banana, 88.9ms
# Speed: 3.2ms preprocess, 88.9ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_212_0.jpg
#
# 0: 384x640 1 banana, 65.0ms
# Speed: 2.3ms preprocess, 65.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_214_0.jpg
#
# 0: 352x640 1 scissors, 62.4ms
# Speed: 2.1ms preprocess, 62.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 448x640 4 bananas, 115.4ms
# Speed: 2.6ms preprocess, 115.4ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_218_0.jpg
# Objet détecté enregistré : detected_objects\banana_218_1.jpg
# Objet détecté enregistré : detected_objects\banana_218_2.jpg
# Objet détecté enregistré : detected_objects\banana_218_3.jpg
#
# 0: 448x640 1 banana, 75.0ms
# Speed: 2.5ms preprocess, 75.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_220_0.jpg
#
# 0: 640x608 2 bananas, 104.6ms
# Speed: 4.9ms preprocess, 104.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
# Objet détecté enregistré : detected_objects\banana_222_0.jpg
# Objet détecté enregistré : detected_objects\banana_222_1.jpg
#
# 0: 320x640 1 banana, 82.0ms
# Speed: 1.4ms preprocess, 82.0ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
# Objet détecté enregistré : detected_objects\banana_224_0.jpg
#
# 0: 512x640 (no detections), 67.9ms
# Speed: 2.1ms preprocess, 67.9ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 6 bananas, 1 dining table, 53.8ms
# Speed: 1.8ms preprocess, 53.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_228_0.jpg
# Objet détecté enregistré : detected_objects\banana_228_1.jpg
# Objet détecté enregistré : detected_objects\banana_228_2.jpg
# Objet détecté enregistré : detected_objects\banana_228_3.jpg
# Objet détecté enregistré : detected_objects\banana_228_4.jpg
# Objet détecté enregistré : detected_objects\banana_228_6.jpg
#
# 0: 320x640 1 banana, 56.0ms
# Speed: 1.8ms preprocess, 56.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
# Objet détecté enregistré : detected_objects\banana_230_0.jpg
#
# 0: 640x448 3 bananas, 61.9ms
# Speed: 3.0ms preprocess, 61.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
# Objet détecté enregistré : detected_objects\banana_232_0.jpg
# Objet détecté enregistré : detected_objects\banana_232_1.jpg
# Objet détecté enregistré : detected_objects\banana_232_2.jpg
#
# 0: 448x640 5 bananas, 66.5ms
# Speed: 2.5ms preprocess, 66.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_234_0.jpg
# Objet détecté enregistré : detected_objects\banana_234_1.jpg
# Objet détecté enregistré : detected_objects\banana_234_2.jpg
# Objet détecté enregistré : detected_objects\banana_234_3.jpg
# Objet détecté enregistré : detected_objects\banana_234_4.jpg
#
# 0: 352x640 1 banana, 98.7ms
# Speed: 1.7ms preprocess, 98.7ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Objet détecté enregistré : detected_objects\banana_236_0.jpg
#
# 0: 256x640 4 bananas, 72.4ms
# Speed: 2.4ms preprocess, 72.4ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 640)
# Objet détecté enregistré : detected_objects\banana_238_0.jpg
# Objet détecté enregistré : detected_objects\banana_238_1.jpg
# Objet détecté enregistré : detected_objects\banana_238_2.jpg
# Objet détecté enregistré : detected_objects\banana_238_3.jpg
#
# 0: 640x608 (no detections), 88.8ms
# Speed: 4.0ms preprocess, 88.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 480x640 1 banana, 83.3ms
# Speed: 3.0ms preprocess, 83.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\banana_242_0.jpg
#
# 0: 640x416 2 bananas, 91.9ms
# Speed: 5.4ms preprocess, 91.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 416)
# Objet détecté enregistré : detected_objects\banana_244_0.jpg
# Objet détecté enregistré : detected_objects\banana_244_1.jpg
#
# 0: 352x640 1 banana, 66.0ms
# Speed: 2.2ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# Objet détecté enregistré : detected_objects\banana_246_0.jpg
#
# 0: 640x384 (no detections), 93.4ms
# Speed: 2.6ms preprocess, 93.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 320x640 6 bananas, 1 apple, 1 orange, 1 cake, 56.5ms
# Speed: 1.7ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# Objet détecté enregistré : detected_objects\banana_250_0.jpg
# Objet détecté enregistré : detected_objects\banana_250_1.jpg
# Objet détecté enregistré : detected_objects\banana_250_2.jpg
# Objet détecté enregistré : detected_objects\apple_250_3.jpg
# Objet détecté enregistré : detected_objects\orange_250_4.jpg
# Objet détecté enregistré : detected_objects\banana_250_5.jpg
# Objet détecté enregistré : detected_objects\banana_250_6.jpg
# Objet détecté enregistré : detected_objects\banana_250_8.jpg
#
# 0: 448x640 3 persons, 1 banana, 64.2ms
# Speed: 2.9ms preprocess, 64.2ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_252_0.jpg
#
# 0: 448x640 1 person, 2 bananas, 67.7ms
# Speed: 2.7ms preprocess, 67.7ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_254_0.jpg
# Objet détecté enregistré : detected_objects\banana_254_2.jpg
#
# 0: 512x640 1 banana, 65.6ms
# Speed: 2.4ms preprocess, 65.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
# Objet détecté enregistré : detected_objects\banana_256_0.jpg
#
# 0: 384x640 1 banana, 1 apple, 131.5ms
# Speed: 1.7ms preprocess, 131.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_258_0.jpg
# Objet détecté enregistré : detected_objects\apple_258_1.jpg
#
# 0: 384x640 1 banana, 179.2ms
# Speed: 7.5ms preprocess, 179.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_260_0.jpg
#
# 0: 576x640 4 bananas, 840.3ms
# Speed: 7.6ms preprocess, 840.3ms inference, 4.6ms postprocess per image at shape (1, 3, 576, 640)
# Objet détecté enregistré : detected_objects\banana_262_0.jpg
# Objet détecté enregistré : detected_objects\banana_262_1.jpg
# Objet détecté enregistré : detected_objects\banana_262_2.jpg
# Objet détecté enregistré : detected_objects\banana_262_3.jpg
#
# 0: 416x640 1 banana, 349.7ms
# Speed: 4.0ms preprocess, 349.7ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
# Objet détecté enregistré : detected_objects\banana_264_0.jpg
#
# 0: 448x640 1 bowl, 7 bananas, 313.0ms
# Speed: 18.2ms preprocess, 313.0ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_266_1.jpg
# Objet détecté enregistré : detected_objects\banana_266_2.jpg
# Objet détecté enregistré : detected_objects\banana_266_3.jpg
# Objet détecté enregistré : detected_objects\banana_266_4.jpg
# Objet détecté enregistré : detected_objects\banana_266_5.jpg
# Objet détecté enregistré : detected_objects\banana_266_6.jpg
# Objet détecté enregistré : detected_objects\banana_266_7.jpg
#
# 0: 448x640 1 banana, 186.5ms
# Speed: 5.4ms preprocess, 186.5ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_268_0.jpg
#
# 0: 640x640 1 toilet, 223.8ms
# Speed: 5.6ms preprocess, 223.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 bananas, 105.7ms
# Speed: 2.4ms preprocess, 105.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_272_0.jpg
# Objet détecté enregistré : detected_objects\banana_272_1.jpg
# Objet détecté enregistré : detected_objects\banana_272_2.jpg
# Objet détecté enregistré : detected_objects\banana_272_3.jpg
# Objet détecté enregistré : detected_objects\banana_272_4.jpg
# Objet détecté enregistré : detected_objects\banana_272_5.jpg
# Objet détecté enregistré : detected_objects\banana_272_6.jpg
#
# 0: 320x640 1 banana, 66.9ms
# Speed: 1.7ms preprocess, 66.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
# Objet détecté enregistré : detected_objects\banana_274_0.jpg
#
# 0: 640x480 2 bananas, 1 teddy bear, 116.2ms
# Speed: 3.7ms preprocess, 116.2ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 480)
# Objet détecté enregistré : detected_objects\banana_276_0.jpg
# Objet détecté enregistré : detected_objects\banana_276_2.jpg
#
# 0: 320x640 1 banana, 66.6ms
# Speed: 1.9ms preprocess, 66.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
# Objet détecté enregistré : detected_objects\banana_278_0.jpg
#
# 0: 320x640 1 banana, 83.1ms
# Speed: 2.0ms preprocess, 83.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
# Objet détecté enregistré : detected_objects\banana_280_0.jpg
#
# 0: 448x640 1 frisbee, 215.3ms
# Speed: 2.8ms preprocess, 215.3ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 banana, 79.6ms
# Speed: 2.6ms preprocess, 79.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_284_0.jpg
#
# 0: 448x640 4 bananas, 80.8ms
# Speed: 2.4ms preprocess, 80.8ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_286_0.jpg
# Objet détecté enregistré : detected_objects\banana_286_1.jpg
# Objet détecté enregistré : detected_objects\banana_286_2.jpg
# Objet détecté enregistré : detected_objects\banana_286_3.jpg
#
# 0: 416x640 1 kite, 66.2ms
# Speed: 3.8ms preprocess, 66.2ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 1 banana, 129.4ms
# Speed: 2.1ms preprocess, 129.4ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_290_0.jpg
#
# 0: 448x640 4 bananas, 143.5ms
# Speed: 2.7ms preprocess, 143.5ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_292_0.jpg
# Objet détecté enregistré : detected_objects\banana_292_1.jpg
# Objet détecté enregistré : detected_objects\banana_292_2.jpg
# Objet détecté enregistré : detected_objects\banana_292_3.jpg
#
# 0: 640x480 1 person, 1 banana, 84.6ms
# Speed: 3.4ms preprocess, 84.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Objet détecté enregistré : detected_objects\banana_294_0.jpg
#
# 0: 352x640 10 oranges, 69.8ms
# Speed: 1.5ms preprocess, 69.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# Objet détecté enregistré : detected_objects\orange_296_0.jpg
# Objet détecté enregistré : detected_objects\orange_296_1.jpg
# Objet détecté enregistré : detected_objects\orange_296_2.jpg
# Objet détecté enregistré : detected_objects\orange_296_3.jpg
# Objet détecté enregistré : detected_objects\orange_296_4.jpg
# Objet détecté enregistré : detected_objects\orange_296_5.jpg
# Objet détecté enregistré : detected_objects\orange_296_6.jpg
# Objet détecté enregistré : detected_objects\orange_296_7.jpg
# Objet détecté enregistré : detected_objects\orange_296_8.jpg
# Objet détecté enregistré : detected_objects\orange_296_9.jpg
#
# 0: 384x640 3 oranges, 65.8ms
# Speed: 1.6ms preprocess, 65.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\orange_298_0.jpg
# Objet détecté enregistré : detected_objects\orange_298_1.jpg
# Objet détecté enregistré : detected_objects\orange_298_2.jpg
#
# 0: 640x640 1 bowl, 1 cake, 98.7ms
# Speed: 4.9ms preprocess, 98.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 1 umbrella, 1 apple, 1 orange, 54.5ms
# Speed: 1.1ms preprocess, 54.5ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# Objet détecté enregistré : detected_objects\apple_302_1.jpg
# Objet détecté enregistré : detected_objects\orange_302_2.jpg
#
# 0: 608x640 1 apple, 1 orange, 106.0ms
# Speed: 3.7ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# Objet détecté enregistré : detected_objects\orange_304_0.jpg
# Objet détecté enregistré : detected_objects\apple_304_1.jpg
#
# 0: 640x640 1 orange, 80.2ms
# Speed: 4.5ms preprocess, 80.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_306_0.jpg
#
# 0: 448x640 13 oranges, 101.4ms
# Speed: 4.6ms preprocess, 101.4ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\orange_308_0.jpg
# Objet détecté enregistré : detected_objects\orange_308_1.jpg
# Objet détecté enregistré : detected_objects\orange_308_2.jpg
# Objet détecté enregistré : detected_objects\orange_308_3.jpg
# Objet détecté enregistré : detected_objects\orange_308_4.jpg
# Objet détecté enregistré : detected_objects\orange_308_5.jpg
# Objet détecté enregistré : detected_objects\orange_308_6.jpg
# Objet détecté enregistré : detected_objects\orange_308_7.jpg
# Objet détecté enregistré : detected_objects\orange_308_8.jpg
# Objet détecté enregistré : detected_objects\orange_308_9.jpg
# Objet détecté enregistré : detected_objects\orange_308_10.jpg
# Objet détecté enregistré : detected_objects\orange_308_11.jpg
# Objet détecté enregistré : detected_objects\orange_308_12.jpg
#
# 0: 640x640 1 orange, 195.3ms
# Speed: 10.7ms preprocess, 195.3ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_310_0.jpg
#
# 0: 448x640 5 oranges, 138.2ms
# Speed: 6.2ms preprocess, 138.2ms inference, 2.8ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\orange_312_0.jpg
# Objet détecté enregistré : detected_objects\orange_312_1.jpg
# Objet détecté enregistré : detected_objects\orange_312_2.jpg
# Objet détecté enregistré : detected_objects\orange_312_3.jpg
# Objet détecté enregistré : detected_objects\orange_312_4.jpg
#
# 0: 640x640 2 oranges, 195.6ms
# Speed: 11.1ms preprocess, 195.6ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_314_0.jpg
# Objet détecté enregistré : detected_objects\orange_314_1.jpg
#
# 0: 480x640 11 oranges, 156.3ms
# Speed: 6.6ms preprocess, 156.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_316_0.jpg
# Objet détecté enregistré : detected_objects\orange_316_1.jpg
# Objet détecté enregistré : detected_objects\orange_316_2.jpg
# Objet détecté enregistré : detected_objects\orange_316_3.jpg
# Objet détecté enregistré : detected_objects\orange_316_4.jpg
# Objet détecté enregistré : detected_objects\orange_316_5.jpg
# Objet détecté enregistré : detected_objects\orange_316_6.jpg
# Objet détecté enregistré : detected_objects\orange_316_7.jpg
# Objet détecté enregistré : detected_objects\orange_316_8.jpg
# Objet détecté enregistré : detected_objects\orange_316_9.jpg
# Objet détecté enregistré : detected_objects\orange_316_10.jpg
#
# 0: 576x640 3 oranges, 167.7ms
# Speed: 9.8ms preprocess, 167.7ms inference, 2.5ms postprocess per image at shape (1, 3, 576, 640)
# Objet détecté enregistré : detected_objects\orange_318_0.jpg
# Objet détecté enregistré : detected_objects\orange_318_1.jpg
# Objet détecté enregistré : detected_objects\orange_318_2.jpg
#
# 0: 608x640 1 orange, 173.9ms
# Speed: 12.0ms preprocess, 173.9ms inference, 2.6ms postprocess per image at shape (1, 3, 608, 640)
# Objet détecté enregistré : detected_objects\orange_320_0.jpg
#
# 0: 384x640 1 bird, 5 oranges, 133.1ms
# Speed: 4.0ms preprocess, 133.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\orange_322_0.jpg
# Objet détecté enregistré : detected_objects\orange_322_1.jpg
# Objet détecté enregistré : detected_objects\orange_322_2.jpg
# Objet détecté enregistré : detected_objects\orange_322_3.jpg
# Objet détecté enregistré : detected_objects\orange_322_4.jpg
#
# 0: 384x640 1 orange, 156.6ms
# Speed: 6.4ms preprocess, 156.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\orange_324_0.jpg
#
# 0: 640x640 6 oranges, 329.1ms
# Speed: 10.9ms preprocess, 329.1ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_326_0.jpg
# Objet détecté enregistré : detected_objects\orange_326_1.jpg
# Objet détecté enregistré : detected_objects\orange_326_2.jpg
# Objet détecté enregistré : detected_objects\orange_326_3.jpg
# Objet détecté enregistré : detected_objects\orange_326_4.jpg
# Objet détecté enregistré : detected_objects\orange_326_5.jpg
#
# 0: 448x640 6 oranges, 1 dining table, 139.6ms
# Speed: 5.3ms preprocess, 139.6ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\orange_328_0.jpg
# Objet détecté enregistré : detected_objects\orange_328_1.jpg
# Objet détecté enregistré : detected_objects\orange_328_2.jpg
# Objet détecté enregistré : detected_objects\orange_328_3.jpg
# Objet détecté enregistré : detected_objects\orange_328_4.jpg
# Objet détecté enregistré : detected_objects\orange_328_5.jpg
#
# 0: 640x640 1 orange, 181.6ms
# Speed: 8.7ms preprocess, 181.6ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_330_0.jpg
#
# 0: 640x640 4 oranges, 190.3ms
# Speed: 12.2ms preprocess, 190.3ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_332_0.jpg
# Objet détecté enregistré : detected_objects\orange_332_1.jpg
# Objet détecté enregistré : detected_objects\orange_332_2.jpg
# Objet détecté enregistré : detected_objects\orange_332_3.jpg
#
# 0: 448x640 4 oranges, 191.6ms
# Speed: 4.8ms preprocess, 191.6ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\orange_334_0.jpg
# Objet détecté enregistré : detected_objects\orange_334_1.jpg
# Objet détecté enregistré : detected_objects\orange_334_2.jpg
# Objet détecté enregistré : detected_objects\orange_334_3.jpg
#
# 0: 640x640 1 orange, 178.2ms
# Speed: 6.9ms preprocess, 178.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_336_0.jpg
#
# 0: 448x640 4 oranges, 1 dining table, 194.8ms
# Speed: 5.6ms preprocess, 194.8ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\orange_338_0.jpg
# Objet détecté enregistré : detected_objects\orange_338_1.jpg
# Objet détecté enregistré : detected_objects\orange_338_2.jpg
# Objet détecté enregistré : detected_objects\orange_338_4.jpg
#
# 0: 640x640 10 oranges, 168.8ms
# Speed: 11.5ms preprocess, 168.8ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_340_0.jpg
# Objet détecté enregistré : detected_objects\orange_340_1.jpg
# Objet détecté enregistré : detected_objects\orange_340_2.jpg
# Objet détecté enregistré : detected_objects\orange_340_3.jpg
# Objet détecté enregistré : detected_objects\orange_340_4.jpg
# Objet détecté enregistré : detected_objects\orange_340_5.jpg
# Objet détecté enregistré : detected_objects\orange_340_6.jpg
# Objet détecté enregistré : detected_objects\orange_340_7.jpg
# Objet détecté enregistré : detected_objects\orange_340_8.jpg
# Objet détecté enregistré : detected_objects\orange_340_9.jpg
#
# 0: 640x640 1 orange, 182.1ms
# Speed: 12.2ms preprocess, 182.1ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_342_0.jpg
#
# 0: 608x640 4 oranges, 187.5ms
# Speed: 12.6ms preprocess, 187.5ms inference, 4.7ms postprocess per image at shape (1, 3, 608, 640)
# Objet détecté enregistré : detected_objects\orange_344_0.jpg
# Objet détecté enregistré : detected_objects\orange_344_1.jpg
# Objet détecté enregistré : detected_objects\orange_344_2.jpg
# Objet détecté enregistré : detected_objects\orange_344_3.jpg
#
# 0: 480x640 3 oranges, 161.2ms
# Speed: 5.4ms preprocess, 161.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_346_0.jpg
# Objet détecté enregistré : detected_objects\orange_346_1.jpg
# Objet détecté enregistré : detected_objects\orange_346_2.jpg
#
# 0: 384x640 1 umbrella, 1 orange, 139.1ms
# Speed: 5.5ms preprocess, 139.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\orange_348_0.jpg
#
# 0: 480x640 2 oranges, 167.3ms
# Speed: 8.1ms preprocess, 167.3ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_350_0.jpg
# Objet détecté enregistré : detected_objects\orange_350_1.jpg
#
# 0: 640x640 (no detections), 196.1ms
# Speed: 8.5ms preprocess, 196.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 6 oranges, 172.8ms
# Speed: 6.3ms preprocess, 172.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_354_0.jpg
# Objet détecté enregistré : detected_objects\orange_354_1.jpg
# Objet détecté enregistré : detected_objects\orange_354_2.jpg
# Objet détecté enregistré : detected_objects\orange_354_3.jpg
# Objet détecté enregistré : detected_objects\orange_354_4.jpg
# Objet détecté enregistré : detected_objects\orange_354_5.jpg
#
# 0: 544x640 1 apple, 1 orange, 222.3ms
# Speed: 8.3ms preprocess, 222.3ms inference, 3.2ms postprocess per image at shape (1, 3, 544, 640)
# Objet détecté enregistré : detected_objects\orange_356_0.jpg
# Objet détecté enregistré : detected_objects\apple_356_1.jpg
#
# 0: 640x640 5 oranges, 215.2ms
# Speed: 12.6ms preprocess, 215.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_358_0.jpg
# Objet détecté enregistré : detected_objects\orange_358_1.jpg
# Objet détecté enregistré : detected_objects\orange_358_2.jpg
# Objet détecté enregistré : detected_objects\orange_358_3.jpg
# Objet détecté enregistré : detected_objects\orange_358_4.jpg
#
# 0: 640x640 1 orange, 203.6ms
# Speed: 9.0ms preprocess, 203.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_360_0.jpg
#
# 0: 480x640 3 oranges, 158.2ms
# Speed: 43.5ms preprocess, 158.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_362_0.jpg
# Objet détecté enregistré : detected_objects\orange_362_1.jpg
# Objet détecté enregistré : detected_objects\orange_362_2.jpg
#
# 0: 416x640 4 oranges, 129.8ms
# Speed: 3.1ms preprocess, 129.8ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
# Objet détecté enregistré : detected_objects\orange_364_0.jpg
# Objet détecté enregistré : detected_objects\orange_364_1.jpg
# Objet détecté enregistré : detected_objects\orange_364_2.jpg
# Objet détecté enregistré : detected_objects\orange_364_3.jpg
#
# 0: 640x640 (no detections), 181.9ms
# Speed: 12.5ms preprocess, 181.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 oranges, 185.9ms
# Speed: 10.3ms preprocess, 185.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_368_0.jpg
# Objet détecté enregistré : detected_objects\orange_368_1.jpg
# Objet détecté enregistré : detected_objects\orange_368_2.jpg
#
# 0: 480x640 1 orange, 150.6ms
# Speed: 6.8ms preprocess, 150.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_370_0.jpg
#
# 0: 608x640 1 orange, 172.2ms
# Speed: 9.4ms preprocess, 172.2ms inference, 2.8ms postprocess per image at shape (1, 3, 608, 640)
# Objet détecté enregistré : detected_objects\orange_372_0.jpg
#
# 0: 544x640 2 oranges, 160.2ms
# Speed: 8.6ms preprocess, 160.2ms inference, 2.0ms postprocess per image at shape (1, 3, 544, 640)
# Objet détecté enregistré : detected_objects\orange_374_0.jpg
# Objet détecté enregistré : detected_objects\orange_374_1.jpg
#
# 0: 480x640 3 oranges, 166.7ms
# Speed: 3.2ms preprocess, 166.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_376_0.jpg
# Objet détecté enregistré : detected_objects\orange_376_1.jpg
# Objet détecté enregistré : detected_objects\orange_376_2.jpg
#
# 0: 640x608 1 umbrella, 1 kite, 2 oranges, 222.2ms
# Speed: 8.9ms preprocess, 222.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
# Objet détecté enregistré : detected_objects\orange_378_0.jpg
# Objet détecté enregistré : detected_objects\orange_378_1.jpg
#
# 0: 512x640 1 apple, 2 oranges, 145.3ms
# Speed: 3.2ms preprocess, 145.3ms inference, 2.6ms postprocess per image at shape (1, 3, 512, 640)
# Objet détecté enregistré : detected_objects\orange_380_0.jpg
# Objet détecté enregistré : detected_objects\apple_380_1.jpg
# Objet détecté enregistré : detected_objects\orange_380_2.jpg
#
# 0: 480x640 3 oranges, 147.8ms
# Speed: 5.8ms preprocess, 147.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_382_0.jpg
# Objet détecté enregistré : detected_objects\orange_382_1.jpg
# Objet détecté enregistré : detected_objects\orange_382_2.jpg
#
# 0: 448x640 3 oranges, 136.8ms
# Speed: 4.7ms preprocess, 136.8ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\orange_384_0.jpg
# Objet détecté enregistré : detected_objects\orange_384_1.jpg
# Objet détecté enregistré : detected_objects\orange_384_2.jpg
#
# 0: 640x640 2 oranges, 203.0ms
# Speed: 8.3ms preprocess, 203.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_386_0.jpg
# Objet détecté enregistré : detected_objects\orange_386_1.jpg
#
# 0: 608x640 1 orange, 187.6ms
# Speed: 10.6ms preprocess, 187.6ms inference, 2.5ms postprocess per image at shape (1, 3, 608, 640)
# Objet détecté enregistré : detected_objects\orange_388_0.jpg
#
# 0: 640x640 5 oranges, 192.5ms
# Speed: 7.1ms preprocess, 192.5ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_390_0.jpg
# Objet détecté enregistré : detected_objects\orange_390_1.jpg
# Objet détecté enregistré : detected_objects\orange_390_2.jpg
# Objet détecté enregistré : detected_objects\orange_390_3.jpg
# Objet détecté enregistré : detected_objects\orange_390_4.jpg
#
# 0: 480x640 1 orange, 173.2ms
# Speed: 6.9ms preprocess, 173.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_392_0.jpg
#
# 0: 544x640 5 oranges, 229.7ms
# Speed: 10.5ms preprocess, 229.7ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
# Objet détecté enregistré : detected_objects\orange_394_0.jpg
# Objet détecté enregistré : detected_objects\orange_394_1.jpg
# Objet détecté enregistré : detected_objects\orange_394_2.jpg
# Objet détecté enregistré : detected_objects\orange_394_3.jpg
# Objet détecté enregistré : detected_objects\orange_394_4.jpg
#
# 0: 640x480 6 oranges, 160.2ms
# Speed: 5.9ms preprocess, 160.2ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 480)
# Objet détecté enregistré : detected_objects\orange_396_0.jpg
# Objet détecté enregistré : detected_objects\orange_396_1.jpg
# Objet détecté enregistré : detected_objects\orange_396_2.jpg
# Objet détecté enregistré : detected_objects\orange_396_3.jpg
# Objet détecté enregistré : detected_objects\orange_396_4.jpg
# Objet détecté enregistré : detected_objects\orange_396_5.jpg
#
# 0: 352x640 3 oranges, 180.2ms
# Speed: 3.1ms preprocess, 180.2ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
# Objet détecté enregistré : detected_objects\orange_398_0.jpg
# Objet détecté enregistré : detected_objects\orange_398_1.jpg
# Objet détecté enregistré : detected_objects\orange_398_2.jpg
#
# 0: 640x640 3 oranges, 181.9ms
# Speed: 14.8ms preprocess, 181.9ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_400_0.jpg
# Objet détecté enregistré : detected_objects\orange_400_1.jpg
# Objet détecté enregistré : detected_objects\orange_400_2.jpg
#
# 0: 480x640 1 orange, 190.6ms
# Speed: 4.7ms preprocess, 190.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_402_0.jpg
#
# 0: 640x608 (no detections), 198.9ms
# Speed: 12.4ms preprocess, 198.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x640 4 oranges, 193.1ms
# Speed: 16.0ms preprocess, 193.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_406_0.jpg
# Objet détecté enregistré : detected_objects\orange_406_1.jpg
# Objet détecté enregistré : detected_objects\orange_406_2.jpg
# Objet détecté enregistré : detected_objects\orange_406_3.jpg
#
# 0: 352x640 5 oranges, 134.1ms
# Speed: 5.2ms preprocess, 134.1ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
# Objet détecté enregistré : detected_objects\orange_408_0.jpg
# Objet détecté enregistré : detected_objects\orange_408_1.jpg
# Objet détecté enregistré : detected_objects\orange_408_2.jpg
# Objet détecté enregistré : detected_objects\orange_408_3.jpg
# Objet détecté enregistré : detected_objects\orange_408_4.jpg
#
# 0: 448x640 2 oranges, 130.8ms
# Speed: 5.4ms preprocess, 130.8ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\orange_410_0.jpg
# Objet détecté enregistré : detected_objects\orange_410_1.jpg
#
# 0: 640x640 2 oranges, 204.4ms
# Speed: 11.4ms preprocess, 204.4ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_412_0.jpg
# Objet détecté enregistré : detected_objects\orange_412_1.jpg
#
# 0: 352x640 2 oranges, 133.0ms
# Speed: 3.2ms preprocess, 133.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
# Objet détecté enregistré : detected_objects\orange_414_0.jpg
# Objet détecté enregistré : detected_objects\orange_414_1.jpg
#
# 0: 512x640 1 orange, 175.1ms
# Speed: 8.5ms preprocess, 175.1ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
# Objet détecté enregistré : detected_objects\orange_416_0.jpg
#
# 0: 416x640 1 wine glass, 6 oranges, 124.8ms
# Speed: 5.4ms preprocess, 124.8ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
# Objet détecté enregistré : detected_objects\orange_418_0.jpg
# Objet détecté enregistré : detected_objects\orange_418_2.jpg
# Objet détecté enregistré : detected_objects\orange_418_3.jpg
# Objet détecté enregistré : detected_objects\orange_418_4.jpg
# Objet détecté enregistré : detected_objects\orange_418_5.jpg
# Objet détecté enregistré : detected_objects\orange_418_6.jpg
#
# 0: 352x640 2 oranges, 118.3ms
# Speed: 5.9ms preprocess, 118.3ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# Objet détecté enregistré : detected_objects\orange_420_0.jpg
# Objet détecté enregistré : detected_objects\orange_420_1.jpg
#
# 0: 480x640 4 oranges, 268.2ms
# Speed: 5.8ms preprocess, 268.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_422_0.jpg
# Objet détecté enregistré : detected_objects\orange_422_1.jpg
# Objet détecté enregistré : detected_objects\orange_422_2.jpg
# Objet détecté enregistré : detected_objects\orange_422_3.jpg
#
# 0: 576x640 1 orange, 161.5ms
# Speed: 12.3ms preprocess, 161.5ms inference, 2.5ms postprocess per image at shape (1, 3, 576, 640)
# Objet détecté enregistré : detected_objects\orange_424_0.jpg
#
# 0: 640x640 1 orange, 178.7ms
# Speed: 9.3ms preprocess, 178.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_426_0.jpg
#
# 0: 480x640 1 orange, 140.3ms
# Speed: 5.0ms preprocess, 140.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_428_0.jpg
#
# 0: 512x640 4 oranges, 149.9ms
# Speed: 5.4ms preprocess, 149.9ms inference, 2.4ms postprocess per image at shape (1, 3, 512, 640)
# Objet détecté enregistré : detected_objects\orange_430_0.jpg
# Objet détecté enregistré : detected_objects\orange_430_1.jpg
# Objet détecté enregistré : detected_objects\orange_430_2.jpg
# Objet détecté enregistré : detected_objects\orange_430_3.jpg
#
# 0: 640x640 1 orange, 242.5ms
# Speed: 11.1ms preprocess, 242.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_432_0.jpg
#
# 0: 448x640 10 oranges, 153.9ms
# Speed: 4.2ms preprocess, 153.9ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\orange_434_0.jpg
# Objet détecté enregistré : detected_objects\orange_434_1.jpg
# Objet détecté enregistré : detected_objects\orange_434_2.jpg
# Objet détecté enregistré : detected_objects\orange_434_3.jpg
# Objet détecté enregistré : detected_objects\orange_434_4.jpg
# Objet détecté enregistré : detected_objects\orange_434_5.jpg
# Objet détecté enregistré : detected_objects\orange_434_6.jpg
# Objet détecté enregistré : detected_objects\orange_434_7.jpg
# Objet détecté enregistré : detected_objects\orange_434_8.jpg
# Objet détecté enregistré : detected_objects\orange_434_9.jpg
#
# 0: 448x640 4 oranges, 131.7ms
# Speed: 5.1ms preprocess, 131.7ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\orange_436_0.jpg
# Objet détecté enregistré : detected_objects\orange_436_1.jpg
# Objet détecté enregistré : detected_objects\orange_436_2.jpg
# Objet détecté enregistré : detected_objects\orange_436_3.jpg
#
# 0: 576x640 3 oranges, 157.9ms
# Speed: 7.7ms preprocess, 157.9ms inference, 2.1ms postprocess per image at shape (1, 3, 576, 640)
# Objet détecté enregistré : detected_objects\orange_438_0.jpg
# Objet détecté enregistré : detected_objects\orange_438_1.jpg
# Objet détecté enregistré : detected_objects\orange_438_2.jpg
# Extraction terminée.

# %%
# Dossier contenant les images extraites par YOLO
dossier = "detected_objects"

# Initialisation d'un tableau pour stocker les descripteurs
tab_descripteurs = []

# Parcourir toutes les images du dossier
for nom_fichier in os.listdir(dossier):
    if nom_fichier.endswith(".jpg"): 
        # Charger l'image
        chemin_image = os.path.join(dossier, nom_fichier)
        image = cv2.imread(chemin_image)

        if image is None:
            print(f"Erreur : Impossible de charger {chemin_image}")
            continue  # Passe à l'image suivante

        # Extraire les descripteurs
        color_features = extract_color_histogram(image)
        shape_features = extract_shape_features(image)
        hog_features = extract_hog_features(image)

        # Vérifier que les descripteurs existent
        if shape_features is None or len(shape_features) == 0:
            shape_features = np.array([0])  # Valeur par défaut si aucun contour

        # Concaténer les descripteurs en un seul vecteur
        feature_vector = np.concatenate([color_features, shape_features, hog_features])

        # Ajouter le vecteur au tableau des descripteurs
        tab_descripteurs.append(feature_vector)


# Convertir la liste en un tableau NumPy final
if tab_descripteurs:
    tab_descripteurs = np.vstack(tab_descripteurs)
else:
    tab_descripteurs = np.array([])  # Tableau vide si aucune image n'a été traitée
    print(" Aucun descripteur n'a été extrait.")

# %% [markdown]
# test avec un mlp

# %%
X = tab_descripteurs  # Ton tableau numpy (features)

labels = [nom.split("_")[0] for nom in os.listdir("detected_objects") if nom.endswith(".jpg")]
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)
y = encoded_labels  # Une liste ou array numpy des classes associées

# Normaliser les données (important pour MLP)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Séparer en train/test (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=1)

# Définir le modèle MLP
mlp = MLPClassifier(hidden_layer_sizes=(30, 10), activation='relu', max_iter=500)

# Entraîner le modèle
mlp.fit(X_train, y_train)

# Prédire sur le test set
y_pred = mlp.predict(X_test)

# Évaluer la précision
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
print(f"Accuracy du modèle : {accuracy:.2f}")
print(f"Précision du modèle : {precision:.2f}")
# Out:
# Accuracy du modèle : 0.80
# Précision du modèle : 0.81

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=1)
rf.fit(X, y)  # Apprentissage avant d'intégrer dans le pipeline

feature_selector = SelectFromModel(rf)

# Créer le pipeline avec le scaler et le modèle MLP
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('FU', FeatureUnion(['scaler', StandardScaler()])),
    ('FS', feature_selector)
])

# Entraîner le pipeline
pipeline.fit(X_train, y_train)

# Évaluer le pipeline
y_pred = pipeline.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

print(f"Accuracy du modèle : {accuracy:.2f}")
print(f"Précision du modèle : {precision:.2f}")

# Sauvegarder le pipeline avec pickle
with open("mlp_pipeline.pkl", "wb") as f:
    pickle.dump(pipeline, f)

print("Pipeline sauvegardé avec succès !")
