# %%
import os
from PIL import Image
import numpy as np
import pandas as pd
import xml.etree.ElementTree as ET  # Pour parser les fichiers XML
import cv2
from ultralytics import YOLO

from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, f1_score
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Data Prep

# %%
def extract_color_histogram(image, bins=(8, 8, 8)):
    # Convertir l'image en espace de couleur HSV
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    
    # Calculer l'histogramme en 3D pour H, S et V
    hist = cv2.calcHist([hsv], [0, 1, 2], None, bins, [0, 180, 0, 256, 0, 256])
    
    # Normaliser l'histogramme
    cv2.normalize(hist, hist)
    
    return hist.flatten()

# %%
def extract_shape_features(image):
    # Convertir en niveaux de gris
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Seuillage pour obtenir un contour net
    _, thresh = cv2.threshold(gray, 128, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)
    
    # Trouver les contours
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Si des contours existent, calculer les moments de Hu
    if contours:
        cnt = max(contours, key=cv2.contourArea)  # Prendre le plus grand contour
        moments = cv2.moments(cnt)
        hu_moments = cv2.HuMoments(moments).flatten()
        
        # Normalisation log
        hu_moments = -np.sign(hu_moments) * np.log10(np.abs(hu_moments) + 1e-10)
        
        return hu_moments
    return None

# %%
def extract_hog_features(image):
    # Convertir en niveaux de gris
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Vérifier que l'image n'est pas vide
    if gray is None or gray.size == 0:
        print("Erreur : Image vide pour HOG")
        return np.array([])  # Retourne un tableau vide si problème

    # Redimensionner l'image à une taille standard (64x128 pour HOG)
    gray = cv2.resize(gray, (64, 128))

    # Définir le descripteur HOG
    hog = cv2.HOGDescriptor()

    # Calculer les descripteurs HOG
    hog_features = hog.compute(gray)

    # Vérifier si le calcul est réussi
    if hog_features is None:
        print("Erreur : Impossible de calculer HOG")
        return np.array([])

    return hog_features.flatten()

# %%
# Charger le modèle YOLO
model = YOLO("yolov8n.pt")

# Dossiers
dossier_origin = "train/"
output_folder = "detected_objects"

# Vérifier et créer le dossier de sortie
os.makedirs(output_folder, exist_ok=True)

# Parcourir toutes les images dans le dossier d'origine
for k, nom_fichier in enumerate(os.listdir(dossier_origin)):
    if nom_fichier.endswith(".jpg"): 
        image_path = os.path.join(dossier_origin, nom_fichier)
        image = cv2.imread(image_path)  # Charger l'image

        if image is None:
            print(f"Erreur : Impossible de charger {image_path}")
            continue

        # Faire la détection sur cette image
        results = model(image)

        # Extraire les objets détectés
        for i, (box, cls) in enumerate(zip(results[0].boxes.xyxy, results[0].boxes.cls)):
            x_min, y_min, x_max, y_max = map(int, box)  # Convertir en entiers
            class_name = model.names[int(cls)]  # Obtenir le nom de la classe détectée

            # Rogner l'objet détecté
            cropped_object = image[y_min:y_max, x_min:x_max]

            # Vérifier si le crop est valide
            if cropped_object.shape[0] == 0 or cropped_object.shape[1] == 0:
                print(f"Avertissement : Objet {class_name} ignoré (zone trop petite)")
                continue

            # Construire le chemin du fichier avec le nom de l'image d'origine
            if class_name in {"banana", "apple", "orange"}:
                filename = os.path.join(output_folder, f"{class_name}_{k}_{i}.jpg")

                # Sauvegarder l'image découpée
                cv2.imwrite(filename, cropped_object)
                print(f"Objet détecté enregistré : {filename}")

print("Extraction terminée.")
# Out:
# 0: 640x640 1 apple, 159.8ms
# Speed: 6.7ms preprocess, 159.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_0_0.jpg
#
# 0: 640x640 1 apple, 117.3ms
# Speed: 5.3ms preprocess, 117.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_2_0.jpg
#
# 0: 448x640 3 apples, 1 carrot, 110.2ms
# Speed: 3.7ms preprocess, 110.2ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_4_0.jpg
# Objet détecté enregistré : detected_objects\apple_4_1.jpg
# Objet détecté enregistré : detected_objects\apple_4_2.jpg
#
# 0: 640x640 2 apples, 114.8ms
# Speed: 4.8ms preprocess, 114.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_6_0.jpg
# Objet détecté enregistré : detected_objects\apple_6_1.jpg
#
# 0: 640x640 3 apples, 115.4ms
# Speed: 3.9ms preprocess, 115.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_8_0.jpg
# Objet détecté enregistré : detected_objects\apple_8_1.jpg
# Objet détecté enregistré : detected_objects\apple_8_2.jpg
#
# 0: 448x640 2 apples, 1 orange, 96.6ms
# Speed: 2.7ms preprocess, 96.6ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\orange_10_0.jpg
# Objet détecté enregistré : detected_objects\apple_10_1.jpg
# Objet détecté enregistré : detected_objects\apple_10_2.jpg
#
# 0: 480x640 1 apple, 115.2ms
# Speed: 2.6ms preprocess, 115.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_12_0.jpg
#
# 0: 608x640 1 apple, 133.0ms
# Speed: 3.8ms preprocess, 133.0ms inference, 1.3ms postprocess per image at shape (1, 3, 608, 640)
# Objet détecté enregistré : detected_objects\apple_14_0.jpg
#
# 0: 640x576 1 apple, 118.7ms
# Speed: 3.4ms preprocess, 118.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 576)
# Objet détecté enregistré : detected_objects\apple_16_0.jpg
#
# 0: 512x640 (no detections), 114.1ms
# Speed: 3.1ms preprocess, 114.1ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 480x640 1 apple, 100.4ms
# Speed: 3.4ms preprocess, 100.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_20_0.jpg
#
# 0: 640x640 1 apple, 114.0ms
# Speed: 4.3ms preprocess, 114.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_22_0.jpg
#
# 0: 640x640 1 stop sign, 1 umbrella, 115.1ms
# Speed: 5.0ms preprocess, 115.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 448x640 2 apples, 105.2ms
# Speed: 2.5ms preprocess, 105.2ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_26_0.jpg
# Objet détecté enregistré : detected_objects\apple_26_1.jpg
#
# 0: 640x640 1 apple, 118.3ms
# Speed: 4.2ms preprocess, 118.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_28_0.jpg
#
# 0: 640x640 3 apples, 129.7ms
# Speed: 5.6ms preprocess, 129.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_30_0.jpg
# Objet détecté enregistré : detected_objects\apple_30_1.jpg
# Objet détecté enregistré : detected_objects\apple_30_2.jpg
#
# 0: 640x448 1 bowl, 4 apples, 1 dining table, 111.5ms
# Speed: 3.7ms preprocess, 111.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 448)
# Objet détecté enregistré : detected_objects\apple_32_1.jpg
# Objet détecté enregistré : detected_objects\apple_32_2.jpg
# Objet détecté enregistré : detected_objects\apple_32_3.jpg
# Objet détecté enregistré : detected_objects\apple_32_5.jpg
#
# 0: 448x640 2 apples, 96.0ms
# Speed: 2.5ms preprocess, 96.0ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_34_0.jpg
# Objet détecté enregistré : detected_objects\apple_34_1.jpg
#
# 0: 448x640 2 apples, 97.1ms
# Speed: 2.2ms preprocess, 97.1ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_36_0.jpg
# Objet détecté enregistré : detected_objects\apple_36_1.jpg
#
# 0: 320x640 3 apples, 99.5ms
# Speed: 1.5ms preprocess, 99.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# Objet détecté enregistré : detected_objects\apple_38_0.jpg
# Objet détecté enregistré : detected_objects\apple_38_1.jpg
# Objet détecté enregistré : detected_objects\apple_38_2.jpg
#
# 0: 640x640 1 apple, 125.2ms
# Speed: 3.7ms preprocess, 125.2ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_40_0.jpg
#
# 0: 640x640 1 apple, 146.4ms
# Speed: 3.4ms preprocess, 146.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_42_0.jpg
#
# 0: 480x640 17 apples, 98.3ms
# Speed: 3.4ms preprocess, 98.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_44_0.jpg
# Objet détecté enregistré : detected_objects\apple_44_1.jpg
# Objet détecté enregistré : detected_objects\apple_44_2.jpg
# Objet détecté enregistré : detected_objects\apple_44_3.jpg
# Objet détecté enregistré : detected_objects\apple_44_4.jpg
# Objet détecté enregistré : detected_objects\apple_44_5.jpg
# Objet détecté enregistré : detected_objects\apple_44_6.jpg
# Objet détecté enregistré : detected_objects\apple_44_7.jpg
# Objet détecté enregistré : detected_objects\apple_44_8.jpg
# Objet détecté enregistré : detected_objects\apple_44_9.jpg
# Objet détecté enregistré : detected_objects\apple_44_10.jpg
# Objet détecté enregistré : detected_objects\apple_44_11.jpg
# Objet détecté enregistré : detected_objects\apple_44_12.jpg
# Objet détecté enregistré : detected_objects\apple_44_13.jpg
# Objet détecté enregistré : detected_objects\apple_44_14.jpg
# Objet détecté enregistré : detected_objects\apple_44_15.jpg
# Objet détecté enregistré : detected_objects\apple_44_16.jpg
#
# 0: 640x640 4 apples, 108.2ms
# Speed: 4.9ms preprocess, 108.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_46_0.jpg
# Objet détecté enregistré : detected_objects\apple_46_1.jpg
# Objet détecté enregistré : detected_objects\apple_46_2.jpg
# Objet détecté enregistré : detected_objects\apple_46_3.jpg
#
# 0: 384x640 3 apples, 1 orange, 105.8ms
# Speed: 1.6ms preprocess, 105.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\apple_48_0.jpg
# Objet détecté enregistré : detected_objects\apple_48_1.jpg
# Objet détecté enregistré : detected_objects\orange_48_2.jpg
# Objet détecté enregistré : detected_objects\apple_48_3.jpg
#
# 0: 480x640 2 apples, 136.7ms
# Speed: 2.7ms preprocess, 136.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_50_0.jpg
# Objet détecté enregistré : detected_objects\apple_50_1.jpg
#
# 0: 640x640 1 apple, 116.1ms
# Speed: 4.1ms preprocess, 116.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_52_0.jpg
#
# 0: 640x448 1 apple, 94.6ms
# Speed: 2.4ms preprocess, 94.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
# Objet détecté enregistré : detected_objects\apple_54_0.jpg
#
# 0: 640x640 (no detections), 106.5ms
# Speed: 2.9ms preprocess, 106.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 608x640 1 apple, 109.8ms
# Speed: 3.7ms preprocess, 109.8ms inference, 1.4ms postprocess per image at shape (1, 3, 608, 640)
# Objet détecté enregistré : detected_objects\apple_58_0.jpg
#
# 0: 640x608 1 kite, 1 apple, 2 oranges, 120.0ms
# Speed: 4.1ms preprocess, 120.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
# Objet détecté enregistré : detected_objects\orange_60_0.jpg
# Objet détecté enregistré : detected_objects\apple_60_1.jpg
# Objet détecté enregistré : detected_objects\orange_60_3.jpg
#
# 0: 384x640 1 apple, 86.1ms
# Speed: 2.6ms preprocess, 86.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\apple_62_0.jpg
#
# 0: 448x640 2 apples, 84.0ms
# Speed: 3.1ms preprocess, 84.0ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_64_0.jpg
# Objet détecté enregistré : detected_objects\apple_64_1.jpg
#
# 0: 416x640 2 apples, 2 oranges, 100.5ms
# Speed: 1.8ms preprocess, 100.5ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
# Objet détecté enregistré : detected_objects\orange_66_0.jpg
# Objet détecté enregistré : detected_objects\apple_66_1.jpg
# Objet détecté enregistré : detected_objects\apple_66_2.jpg
# Objet détecté enregistré : detected_objects\orange_66_3.jpg
#
# 0: 544x640 1 vase, 140.2ms
# Speed: 4.6ms preprocess, 140.2ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 640x640 1 apple, 118.4ms
# Speed: 5.5ms preprocess, 118.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_70_0.jpg
#
# 0: 640x640 (no detections), 123.3ms
# Speed: 4.8ms preprocess, 123.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 apple, 108.2ms
# Speed: 4.5ms preprocess, 108.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_74_0.jpg
#
# 0: 512x640 2 apples, 1 orange, 101.4ms
# Speed: 2.8ms preprocess, 101.4ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
# Objet détecté enregistré : detected_objects\apple_76_0.jpg
# Objet détecté enregistré : detected_objects\apple_76_1.jpg
# Objet détecté enregistré : detected_objects\orange_76_2.jpg
#
# 0: 480x640 6 apples, 93.9ms
# Speed: 1.9ms preprocess, 93.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_78_0.jpg
# Objet détecté enregistré : detected_objects\apple_78_1.jpg
# Objet détecté enregistré : detected_objects\apple_78_2.jpg
# Objet détecté enregistré : detected_objects\apple_78_3.jpg
# Objet détecté enregistré : detected_objects\apple_78_4.jpg
# Objet détecté enregistré : detected_objects\apple_78_5.jpg
#
# 0: 448x640 4 apples, 90.2ms
# Speed: 2.8ms preprocess, 90.2ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_80_0.jpg
# Objet détecté enregistré : detected_objects\apple_80_1.jpg
# Objet détecté enregistré : detected_objects\apple_80_2.jpg
# Objet détecté enregistré : detected_objects\apple_80_3.jpg
#
# 0: 448x640 2 apples, 96.8ms
# Speed: 2.1ms preprocess, 96.8ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_82_0.jpg
# Objet détecté enregistré : detected_objects\apple_82_1.jpg
#
# 0: 640x608 1 cake, 129.3ms
# Speed: 3.8ms preprocess, 129.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 384x640 8 apples, 102.9ms
# Speed: 1.5ms preprocess, 102.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\apple_86_0.jpg
# Objet détecté enregistré : detected_objects\apple_86_1.jpg
# Objet détecté enregistré : detected_objects\apple_86_2.jpg
# Objet détecté enregistré : detected_objects\apple_86_3.jpg
# Objet détecté enregistré : detected_objects\apple_86_4.jpg
# Objet détecté enregistré : detected_objects\apple_86_5.jpg
# Objet détecté enregistré : detected_objects\apple_86_6.jpg
# Objet détecté enregistré : detected_objects\apple_86_7.jpg
#
# 0: 512x640 4 apples, 108.4ms
# Speed: 2.9ms preprocess, 108.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Objet détecté enregistré : detected_objects\apple_88_0.jpg
# Objet détecté enregistré : detected_objects\apple_88_1.jpg
# Objet détecté enregistré : detected_objects\apple_88_2.jpg
# Objet détecté enregistré : detected_objects\apple_88_3.jpg
#
# 0: 640x576 1 apple, 110.9ms
# Speed: 3.2ms preprocess, 110.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 576)
# Objet détecté enregistré : detected_objects\apple_90_0.jpg
#
# 0: 640x640 6 apples, 110.7ms
# Speed: 4.1ms preprocess, 110.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_92_0.jpg
# Objet détecté enregistré : detected_objects\apple_92_1.jpg
# Objet détecté enregistré : detected_objects\apple_92_2.jpg
# Objet détecté enregistré : detected_objects\apple_92_3.jpg
# Objet détecté enregistré : detected_objects\apple_92_4.jpg
# Objet détecté enregistré : detected_objects\apple_92_5.jpg
#
# 0: 576x640 1 apple, 115.0ms
# Speed: 4.3ms preprocess, 115.0ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# Objet détecté enregistré : detected_objects\apple_94_0.jpg
#
# 0: 608x640 1 apple, 1 donut, 114.9ms
# Speed: 3.9ms preprocess, 114.9ms inference, 0.9ms postprocess per image at shape (1, 3, 608, 640)
# Objet détecté enregistré : detected_objects\apple_96_0.jpg
#
# 0: 448x640 6 apples, 2 oranges, 111.8ms
# Speed: 2.7ms preprocess, 111.8ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_98_0.jpg
# Objet détecté enregistré : detected_objects\apple_98_1.jpg
# Objet détecté enregistré : detected_objects\apple_98_2.jpg
# Objet détecté enregistré : detected_objects\apple_98_3.jpg
# Objet détecté enregistré : detected_objects\apple_98_4.jpg
# Objet détecté enregistré : detected_objects\apple_98_5.jpg
# Objet détecté enregistré : detected_objects\orange_98_6.jpg
# Objet détecté enregistré : detected_objects\orange_98_7.jpg
#
# 0: 480x640 1 apple, 106.8ms
# Speed: 2.8ms preprocess, 106.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_100_0.jpg
#
# 0: 448x640 1 apple, 108.8ms
# Speed: 2.5ms preprocess, 108.8ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_102_0.jpg
#
# 0: 640x576 4 apples, 132.6ms
# Speed: 4.0ms preprocess, 132.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 576)
# Objet détecté enregistré : detected_objects\apple_104_0.jpg
# Objet détecté enregistré : detected_objects\apple_104_1.jpg
# Objet détecté enregistré : detected_objects\apple_104_2.jpg
# Objet détecté enregistré : detected_objects\apple_104_3.jpg
#
# 0: 480x640 2 apples, 1 orange, 104.3ms
# Speed: 2.5ms preprocess, 104.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_106_0.jpg
# Objet détecté enregistré : detected_objects\apple_106_1.jpg
# Objet détecté enregistré : detected_objects\orange_106_2.jpg
#
# 0: 416x640 3 apples, 1 orange, 87.1ms
# Speed: 1.9ms preprocess, 87.1ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
# Objet détecté enregistré : detected_objects\apple_108_0.jpg
# Objet détecté enregistré : detected_objects\orange_108_1.jpg
# Objet détecté enregistré : detected_objects\apple_108_2.jpg
# Objet détecté enregistré : detected_objects\apple_108_3.jpg
#
# 0: 640x640 8 apples, 135.8ms
# Speed: 3.8ms preprocess, 135.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_110_0.jpg
# Objet détecté enregistré : detected_objects\apple_110_1.jpg
# Objet détecté enregistré : detected_objects\apple_110_2.jpg
# Objet détecté enregistré : detected_objects\apple_110_3.jpg
# Objet détecté enregistré : detected_objects\apple_110_4.jpg
# Objet détecté enregistré : detected_objects\apple_110_5.jpg
# Objet détecté enregistré : detected_objects\apple_110_6.jpg
# Objet détecté enregistré : detected_objects\apple_110_7.jpg
#
# 0: 640x640 2 apples, 1 orange, 126.3ms
# Speed: 3.8ms preprocess, 126.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_112_0.jpg
# Objet détecté enregistré : detected_objects\orange_112_1.jpg
# Objet détecté enregistré : detected_objects\apple_112_2.jpg
#
# 0: 448x640 1 apple, 93.5ms
# Speed: 2.8ms preprocess, 93.5ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_114_0.jpg
#
# 0: 384x640 4 apples, 1 orange, 96.1ms
# Speed: 1.6ms preprocess, 96.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\apple_116_0.jpg
# Objet détecté enregistré : detected_objects\apple_116_1.jpg
# Objet détecté enregistré : detected_objects\apple_116_2.jpg
# Objet détecté enregistré : detected_objects\apple_116_3.jpg
# Objet détecté enregistré : detected_objects\orange_116_4.jpg
#
# 0: 640x640 3 apples, 156.6ms
# Speed: 2.7ms preprocess, 156.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_118_0.jpg
# Objet détecté enregistré : detected_objects\apple_118_1.jpg
# Objet détecté enregistré : detected_objects\apple_118_2.jpg
#
# 0: 480x640 5 apples, 94.3ms
# Speed: 3.2ms preprocess, 94.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_120_0.jpg
# Objet détecté enregistré : detected_objects\apple_120_1.jpg
# Objet détecté enregistré : detected_objects\apple_120_2.jpg
# Objet détecté enregistré : detected_objects\apple_120_3.jpg
# Objet détecté enregistré : detected_objects\apple_120_4.jpg
#
# 0: 480x640 3 apples, 95.8ms
# Speed: 2.0ms preprocess, 95.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_122_0.jpg
# Objet détecté enregistré : detected_objects\apple_122_1.jpg
# Objet détecté enregistré : detected_objects\apple_122_2.jpg
#
# 0: 512x640 3 apples, 98.6ms
# Speed: 3.3ms preprocess, 98.6ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
# Objet détecté enregistré : detected_objects\apple_124_0.jpg
# Objet détecté enregistré : detected_objects\apple_124_1.jpg
# Objet détecté enregistré : detected_objects\apple_124_2.jpg
#
# 0: 640x640 2 apples, 107.6ms
# Speed: 4.6ms preprocess, 107.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_126_0.jpg
# Objet détecté enregistré : detected_objects\apple_126_1.jpg
#
# 0: 640x640 3 apples, 118.6ms
# Speed: 3.6ms preprocess, 118.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_128_0.jpg
# Objet détecté enregistré : detected_objects\apple_128_1.jpg
# Objet détecté enregistré : detected_objects\apple_128_2.jpg
#
# 0: 640x640 1 apple, 122.7ms
# Speed: 4.7ms preprocess, 122.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_130_0.jpg
#
# 0: 640x512 1 apple, 140.6ms
# Speed: 2.6ms preprocess, 140.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
# Objet détecté enregistré : detected_objects\apple_132_0.jpg
#
# 0: 384x640 4 apples, 96.4ms
# Speed: 2.0ms preprocess, 96.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\apple_134_0.jpg
# Objet détecté enregistré : detected_objects\apple_134_1.jpg
# Objet détecté enregistré : detected_objects\apple_134_2.jpg
# Objet détecté enregistré : detected_objects\apple_134_3.jpg
#
# 0: 640x640 1 apple, 124.7ms
# Speed: 4.6ms preprocess, 124.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_136_0.jpg
#
# 0: 640x640 1 apple, 124.7ms
# Speed: 3.5ms preprocess, 124.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_138_0.jpg
#
# 0: 640x640 2 apples, 111.1ms
# Speed: 4.4ms preprocess, 111.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_140_0.jpg
# Objet détecté enregistré : detected_objects\apple_140_1.jpg
#
# 0: 640x640 1 apple, 122.6ms
# Speed: 3.4ms preprocess, 122.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\apple_142_0.jpg
#
# 0: 512x640 2 apples, 106.1ms
# Speed: 2.7ms preprocess, 106.1ms inference, 2.3ms postprocess per image at shape (1, 3, 512, 640)
# Objet détecté enregistré : detected_objects\apple_144_0.jpg
# Objet détecté enregistré : detected_objects\apple_144_1.jpg
#
# 0: 480x640 1 apple, 111.7ms
# Speed: 1.6ms preprocess, 111.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_146_0.jpg
#
# 0: 480x640 1 apple, 97.7ms
# Speed: 2.1ms preprocess, 97.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_148_0.jpg
#
# 0: 384x640 1 banana, 105.1ms
# Speed: 1.6ms preprocess, 105.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_150_0.jpg
#
# 0: 448x640 4 bananas, 98.4ms
# Speed: 3.6ms preprocess, 98.4ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_152_0.jpg
# Objet détecté enregistré : detected_objects\banana_152_1.jpg
# Objet détecté enregistré : detected_objects\banana_152_2.jpg
# Objet détecté enregistré : detected_objects\banana_152_3.jpg
#
# 0: 640x640 1 scissors, 106.9ms
# Speed: 4.6ms preprocess, 106.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 banana, 120.1ms
# Speed: 2.4ms preprocess, 120.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\banana_156_0.jpg
#
# 0: 640x640 1 kite, 122.0ms
# Speed: 4.5ms preprocess, 122.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 512x640 1 bowl, 1 banana, 1 dining table, 93.8ms
# Speed: 3.9ms preprocess, 93.8ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
# Objet détecté enregistré : detected_objects\banana_160_0.jpg
#
# 0: 384x640 1 banana, 1 scissors, 86.0ms
# Speed: 1.7ms preprocess, 86.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_162_1.jpg
#
# 0: 640x640 4 bananas, 129.1ms
# Speed: 2.5ms preprocess, 129.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\banana_164_0.jpg
# Objet détecté enregistré : detected_objects\banana_164_1.jpg
# Objet détecté enregistré : detected_objects\banana_164_2.jpg
# Objet détecté enregistré : detected_objects\banana_164_3.jpg
#
# 0: 544x640 (no detections), 132.9ms
# Speed: 4.0ms preprocess, 132.9ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 banana, 100.6ms
# Speed: 1.9ms preprocess, 100.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_168_0.jpg
#
# 0: 384x640 1 banana, 96.3ms
# Speed: 1.6ms preprocess, 96.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_170_0.jpg
#
# 0: 448x640 4 bananas, 116.6ms
# Speed: 1.7ms preprocess, 116.6ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_172_0.jpg
# Objet détecté enregistré : detected_objects\banana_172_1.jpg
# Objet détecté enregistré : detected_objects\banana_172_2.jpg
# Objet détecté enregistré : detected_objects\banana_172_3.jpg
#
# 0: 352x640 1 banana, 104.2ms
# Speed: 1.7ms preprocess, 104.2ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
# Objet détecté enregistré : detected_objects\banana_174_0.jpg
#
# 0: 352x640 1 banana, 98.6ms
# Speed: 1.2ms preprocess, 98.6ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
# Objet détecté enregistré : detected_objects\banana_176_0.jpg
#
# 0: 640x448 2 bananas, 122.3ms
# Speed: 2.1ms preprocess, 122.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
# Objet détecté enregistré : detected_objects\banana_178_0.jpg
# Objet détecté enregistré : detected_objects\banana_178_1.jpg
#
# 0: 352x640 1 banana, 128.1ms
# Speed: 1.8ms preprocess, 128.1ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
# Objet détecté enregistré : detected_objects\banana_180_0.jpg
#
# 0: 512x640 4 bananas, 99.9ms
# Speed: 2.2ms preprocess, 99.9ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
# Objet détecté enregistré : detected_objects\banana_182_0.jpg
# Objet détecté enregistré : detected_objects\banana_182_1.jpg
# Objet détecté enregistré : detected_objects\banana_182_2.jpg
# Objet détecté enregistré : detected_objects\banana_182_3.jpg
#
# 0: 640x640 1 banana, 115.4ms
# Speed: 4.7ms preprocess, 115.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\banana_184_0.jpg
#
# 0: 480x640 1 banana, 93.9ms
# Speed: 2.7ms preprocess, 93.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\banana_186_0.jpg
#
# 0: 448x640 1 banana, 92.3ms
# Speed: 1.7ms preprocess, 92.3ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_188_0.jpg
#
# 0: 512x640 2 bananas, 112.9ms
# Speed: 2.1ms preprocess, 112.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
# Objet détecté enregistré : detected_objects\banana_190_0.jpg
# Objet détecté enregistré : detected_objects\banana_190_1.jpg
#
# 0: 384x640 1 banana, 86.7ms
# Speed: 1.5ms preprocess, 86.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_192_0.jpg
#
# 0: 544x640 3 bananas, 109.4ms
# Speed: 2.6ms preprocess, 109.4ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
# Objet détecté enregistré : detected_objects\banana_194_0.jpg
# Objet détecté enregistré : detected_objects\banana_194_1.jpg
# Objet détecté enregistré : detected_objects\banana_194_2.jpg
#
# 0: 480x640 (no detections), 101.6ms
# Speed: 1.9ms preprocess, 101.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x608 2 bananas, 152.4ms
# Speed: 4.4ms preprocess, 152.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
# Objet détecté enregistré : detected_objects\banana_198_0.jpg
# Objet détecté enregistré : detected_objects\banana_198_1.jpg
#
# 0: 448x640 1 banana, 2 apples, 2 oranges, 123.8ms
# Speed: 2.2ms preprocess, 123.8ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_200_0.jpg
# Objet détecté enregistré : detected_objects\banana_200_1.jpg
# Objet détecté enregistré : detected_objects\orange_200_2.jpg
# Objet détecté enregistré : detected_objects\apple_200_3.jpg
# Objet détecté enregistré : detected_objects\orange_200_4.jpg
#
# 0: 416x640 1 banana, 91.2ms
# Speed: 2.9ms preprocess, 91.2ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
# Objet détecté enregistré : detected_objects\banana_202_0.jpg
#
# 0: 384x640 9 bananas, 84.4ms
# Speed: 1.8ms preprocess, 84.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_204_0.jpg
# Objet détecté enregistré : detected_objects\banana_204_1.jpg
# Objet détecté enregistré : detected_objects\banana_204_2.jpg
# Objet détecté enregistré : detected_objects\banana_204_3.jpg
# Objet détecté enregistré : detected_objects\banana_204_4.jpg
# Objet détecté enregistré : detected_objects\banana_204_5.jpg
# Objet détecté enregistré : detected_objects\banana_204_6.jpg
# Objet détecté enregistré : detected_objects\banana_204_7.jpg
# Objet détecté enregistré : detected_objects\banana_204_8.jpg
#
# 0: 544x640 2 bananas, 105.4ms
# Speed: 4.7ms preprocess, 105.4ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
# Objet détecté enregistré : detected_objects\banana_206_0.jpg
# Objet détecté enregistré : detected_objects\banana_206_1.jpg
#
# 0: 640x640 1 banana, 116.6ms
# Speed: 3.8ms preprocess, 116.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\banana_208_0.jpg
#
# 0: 448x640 2 bananas, 1 dining table, 91.5ms
# Speed: 1.9ms preprocess, 91.5ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_210_0.jpg
# Objet détecté enregistré : detected_objects\banana_210_1.jpg
#
# 0: 448x640 1 banana, 90.7ms
# Speed: 1.7ms preprocess, 90.7ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_212_0.jpg
#
# 0: 384x640 1 banana, 82.6ms
# Speed: 1.9ms preprocess, 82.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_214_0.jpg
#
# 0: 352x640 1 scissors, 84.1ms
# Speed: 1.6ms preprocess, 84.1ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 448x640 4 bananas, 96.0ms
# Speed: 2.1ms preprocess, 96.0ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_218_0.jpg
# Objet détecté enregistré : detected_objects\banana_218_1.jpg
# Objet détecté enregistré : detected_objects\banana_218_2.jpg
# Objet détecté enregistré : detected_objects\banana_218_3.jpg
#
# 0: 448x640 1 banana, 109.2ms
# Speed: 1.8ms preprocess, 109.2ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_220_0.jpg
#
# 0: 640x608 2 bananas, 114.7ms
# Speed: 4.8ms preprocess, 114.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 608)
# Objet détecté enregistré : detected_objects\banana_222_0.jpg
# Objet détecté enregistré : detected_objects\banana_222_1.jpg
#
# 0: 320x640 1 banana, 92.4ms
# Speed: 1.7ms preprocess, 92.4ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
# Objet détecté enregistré : detected_objects\banana_224_0.jpg
#
# 0: 512x640 (no detections), 105.0ms
# Speed: 2.3ms preprocess, 105.0ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 6 bananas, 1 dining table, 95.6ms
# Speed: 2.5ms preprocess, 95.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_228_0.jpg
# Objet détecté enregistré : detected_objects\banana_228_1.jpg
# Objet détecté enregistré : detected_objects\banana_228_2.jpg
# Objet détecté enregistré : detected_objects\banana_228_3.jpg
# Objet détecté enregistré : detected_objects\banana_228_4.jpg
# Objet détecté enregistré : detected_objects\banana_228_6.jpg
#
# 0: 320x640 1 banana, 74.5ms
# Speed: 1.5ms preprocess, 74.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
# Objet détecté enregistré : detected_objects\banana_230_0.jpg
#
# 0: 640x448 3 bananas, 132.6ms
# Speed: 2.2ms preprocess, 132.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
# Objet détecté enregistré : detected_objects\banana_232_0.jpg
# Objet détecté enregistré : detected_objects\banana_232_1.jpg
# Objet détecté enregistré : detected_objects\banana_232_2.jpg
#
# 0: 448x640 5 bananas, 95.1ms
# Speed: 1.7ms preprocess, 95.1ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_234_0.jpg
# Objet détecté enregistré : detected_objects\banana_234_1.jpg
# Objet détecté enregistré : detected_objects\banana_234_2.jpg
# Objet détecté enregistré : detected_objects\banana_234_3.jpg
# Objet détecté enregistré : detected_objects\banana_234_4.jpg
#
# 0: 352x640 1 banana, 86.3ms
# Speed: 1.5ms preprocess, 86.3ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# Objet détecté enregistré : detected_objects\banana_236_0.jpg
#
# 0: 256x640 4 bananas, 93.6ms
# Speed: 1.7ms preprocess, 93.6ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 640)
# Objet détecté enregistré : detected_objects\banana_238_0.jpg
# Objet détecté enregistré : detected_objects\banana_238_1.jpg
# Objet détecté enregistré : detected_objects\banana_238_2.jpg
# Objet détecté enregistré : detected_objects\banana_238_3.jpg
#
# 0: 640x608 (no detections), 107.2ms
# Speed: 4.0ms preprocess, 107.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 480x640 1 banana, 93.5ms
# Speed: 3.3ms preprocess, 93.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\banana_242_0.jpg
#
# 0: 640x416 2 bananas, 108.2ms
# Speed: 2.5ms preprocess, 108.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
# Objet détecté enregistré : detected_objects\banana_244_0.jpg
# Objet détecté enregistré : detected_objects\banana_244_1.jpg
#
# 0: 352x640 1 banana, 84.1ms
# Speed: 1.8ms preprocess, 84.1ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
# Objet détecté enregistré : detected_objects\banana_246_0.jpg
#
# 0: 640x384 (no detections), 120.1ms
# Speed: 3.1ms preprocess, 120.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 320x640 6 bananas, 1 apple, 1 orange, 1 cake, 82.0ms
# Speed: 1.8ms preprocess, 82.0ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
# Objet détecté enregistré : detected_objects\banana_250_0.jpg
# Objet détecté enregistré : detected_objects\banana_250_1.jpg
# Objet détecté enregistré : detected_objects\banana_250_2.jpg
# Objet détecté enregistré : detected_objects\apple_250_3.jpg
# Objet détecté enregistré : detected_objects\orange_250_4.jpg
# Objet détecté enregistré : detected_objects\banana_250_5.jpg
# Objet détecté enregistré : detected_objects\banana_250_6.jpg
# Objet détecté enregistré : detected_objects\banana_250_8.jpg
#
# 0: 448x640 3 persons, 1 banana, 103.2ms
# Speed: 2.1ms preprocess, 103.2ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_252_0.jpg
#
# 0: 448x640 1 person, 2 bananas, 95.3ms
# Speed: 2.4ms preprocess, 95.3ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_254_0.jpg
# Objet détecté enregistré : detected_objects\banana_254_2.jpg
#
# 0: 512x640 1 banana, 134.9ms
# Speed: 5.9ms preprocess, 134.9ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
# Objet détecté enregistré : detected_objects\banana_256_0.jpg
#
# 0: 384x640 1 banana, 1 apple, 102.5ms
# Speed: 3.3ms preprocess, 102.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_258_0.jpg
# Objet détecté enregistré : detected_objects\apple_258_1.jpg
#
# 0: 384x640 1 banana, 93.6ms
# Speed: 2.8ms preprocess, 93.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_260_0.jpg
#
# 0: 576x640 4 bananas, 148.7ms
# Speed: 4.7ms preprocess, 148.7ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
# Objet détecté enregistré : detected_objects\banana_262_0.jpg
# Objet détecté enregistré : detected_objects\banana_262_1.jpg
# Objet détecté enregistré : detected_objects\banana_262_2.jpg
# Objet détecté enregistré : detected_objects\banana_262_3.jpg
#
# 0: 416x640 1 banana, 119.6ms
# Speed: 3.4ms preprocess, 119.6ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
# Objet détecté enregistré : detected_objects\banana_264_0.jpg
#
# 0: 448x640 1 bowl, 7 bananas, 114.5ms
# Speed: 1.8ms preprocess, 114.5ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_266_1.jpg
# Objet détecté enregistré : detected_objects\banana_266_2.jpg
# Objet détecté enregistré : detected_objects\banana_266_3.jpg
# Objet détecté enregistré : detected_objects\banana_266_4.jpg
# Objet détecté enregistré : detected_objects\banana_266_5.jpg
# Objet détecté enregistré : detected_objects\banana_266_6.jpg
# Objet détecté enregistré : detected_objects\banana_266_7.jpg
#
# 0: 448x640 1 banana, 96.4ms
# Speed: 2.8ms preprocess, 96.4ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_268_0.jpg
#
# 0: 640x640 1 toilet, 128.2ms
# Speed: 3.3ms preprocess, 128.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 bananas, 81.3ms
# Speed: 2.7ms preprocess, 81.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_272_0.jpg
# Objet détecté enregistré : detected_objects\banana_272_1.jpg
# Objet détecté enregistré : detected_objects\banana_272_2.jpg
# Objet détecté enregistré : detected_objects\banana_272_3.jpg
# Objet détecté enregistré : detected_objects\banana_272_4.jpg
# Objet détecté enregistré : detected_objects\banana_272_5.jpg
# Objet détecté enregistré : detected_objects\banana_272_6.jpg
#
# 0: 320x640 1 banana, 75.2ms
# Speed: 2.0ms preprocess, 75.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
# Objet détecté enregistré : detected_objects\banana_274_0.jpg
#
# 0: 640x480 2 bananas, 1 teddy bear, 125.4ms
# Speed: 2.2ms preprocess, 125.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
# Objet détecté enregistré : detected_objects\banana_276_0.jpg
# Objet détecté enregistré : detected_objects\banana_276_2.jpg
#
# 0: 320x640 1 banana, 76.9ms
# Speed: 1.6ms preprocess, 76.9ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# Objet détecté enregistré : detected_objects\banana_278_0.jpg
#
# 0: 320x640 1 banana, 79.1ms
# Speed: 1.7ms preprocess, 79.1ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# Objet détecté enregistré : detected_objects\banana_280_0.jpg
#
# 0: 448x640 1 frisbee, 88.9ms
# Speed: 2.3ms preprocess, 88.9ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 banana, 85.4ms
# Speed: 2.0ms preprocess, 85.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_284_0.jpg
#
# 0: 448x640 4 bananas, 103.8ms
# Speed: 2.3ms preprocess, 103.8ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_286_0.jpg
# Objet détecté enregistré : detected_objects\banana_286_1.jpg
# Objet détecté enregistré : detected_objects\banana_286_2.jpg
# Objet détecté enregistré : detected_objects\banana_286_3.jpg
#
# 0: 416x640 1 kite, 94.7ms
# Speed: 2.8ms preprocess, 94.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 1 banana, 90.1ms
# Speed: 2.0ms preprocess, 90.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\banana_290_0.jpg
#
# 0: 448x640 4 bananas, 76.1ms
# Speed: 2.3ms preprocess, 76.1ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_292_0.jpg
# Objet détecté enregistré : detected_objects\banana_292_1.jpg
# Objet détecté enregistré : detected_objects\banana_292_2.jpg
# Objet détecté enregistré : detected_objects\banana_292_3.jpg
#
# 0: 640x480 1 person, 1 banana, 133.5ms
# Speed: 2.9ms preprocess, 133.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
# Objet détecté enregistré : detected_objects\banana_294_0.jpg
#
# 0: 480x640 1 banana, 1 apple, 1 orange, 98.5ms
# Speed: 1.8ms preprocess, 98.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_296_0.jpg
# Objet détecté enregistré : detected_objects\orange_296_1.jpg
# Objet détecté enregistré : detected_objects\banana_296_2.jpg
#
# 0: 448x640 1 banana, 1 apple, 1 orange, 121.0ms
# Speed: 1.8ms preprocess, 121.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\banana_298_0.jpg
# Objet détecté enregistré : detected_objects\orange_298_1.jpg
# Objet détecté enregistré : detected_objects\apple_298_2.jpg
#
# 0: 480x640 2 bananas, 2 apples, 1 orange, 1 dining table, 126.3ms
# Speed: 3.0ms preprocess, 126.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_300_0.jpg
# Objet détecté enregistré : detected_objects\apple_300_1.jpg
# Objet détecté enregistré : detected_objects\apple_300_2.jpg
# Objet détecté enregistré : detected_objects\banana_300_3.jpg
# Objet détecté enregistré : detected_objects\banana_300_4.jpg
#
# 0: 416x640 1 banana, 1 apple, 1 orange, 114.9ms
# Speed: 1.9ms preprocess, 114.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# Objet détecté enregistré : detected_objects\orange_302_0.jpg
# Objet détecté enregistré : detected_objects\apple_302_1.jpg
# Objet détecté enregistré : detected_objects\banana_302_2.jpg
#
# 0: 480x640 2 bananas, 2 apples, 1 orange, 115.6ms
# Speed: 1.8ms preprocess, 115.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\apple_304_0.jpg
# Objet détecté enregistré : detected_objects\orange_304_1.jpg
# Objet détecté enregistré : detected_objects\banana_304_2.jpg
# Objet détecté enregistré : detected_objects\banana_304_3.jpg
# Objet détecté enregistré : detected_objects\apple_304_4.jpg
#
# 0: 576x640 1 banana, 1 apple, 101.4ms
# Speed: 4.6ms preprocess, 101.4ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# Objet détecté enregistré : detected_objects\apple_306_0.jpg
# Objet détecté enregistré : detected_objects\banana_306_1.jpg
#
# 0: 448x640 1 banana, 1 apple, 1 orange, 86.6ms
# Speed: 2.9ms preprocess, 86.6ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\orange_308_0.jpg
# Objet détecté enregistré : detected_objects\banana_308_1.jpg
# Objet détecté enregistré : detected_objects\apple_308_2.jpg
#
# 0: 608x640 1 apple, 4 oranges, 138.4ms
# Speed: 3.5ms preprocess, 138.4ms inference, 2.7ms postprocess per image at shape (1, 3, 608, 640)
# Objet détecté enregistré : detected_objects\orange_310_0.jpg
# Objet détecté enregistré : detected_objects\orange_310_1.jpg
# Objet détecté enregistré : detected_objects\apple_310_2.jpg
# Objet détecté enregistré : detected_objects\orange_310_3.jpg
# Objet détecté enregistré : detected_objects\orange_310_4.jpg
#
# 0: 448x640 3 bananas, 9 apples, 5 oranges, 132.1ms
# Speed: 2.0ms preprocess, 132.1ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\apple_312_0.jpg
# Objet détecté enregistré : detected_objects\orange_312_1.jpg
# Objet détecté enregistré : detected_objects\banana_312_2.jpg
# Objet détecté enregistré : detected_objects\apple_312_3.jpg
# Objet détecté enregistré : detected_objects\orange_312_4.jpg
# Objet détecté enregistré : detected_objects\apple_312_5.jpg
# Objet détecté enregistré : detected_objects\orange_312_6.jpg
# Objet détecté enregistré : detected_objects\apple_312_7.jpg
# Objet détecté enregistré : detected_objects\orange_312_8.jpg
# Objet détecté enregistré : detected_objects\apple_312_9.jpg
# Objet détecté enregistré : detected_objects\apple_312_10.jpg
# Objet détecté enregistré : detected_objects\banana_312_11.jpg
# Objet détecté enregistré : detected_objects\apple_312_12.jpg
# Objet détecté enregistré : detected_objects\banana_312_13.jpg
# Objet détecté enregistré : detected_objects\apple_312_14.jpg
# Objet détecté enregistré : detected_objects\orange_312_15.jpg
# Objet détecté enregistré : detected_objects\apple_312_16.jpg
#
# 0: 448x640 2 bananas, 2 oranges, 99.9ms
# Speed: 2.2ms preprocess, 99.9ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\orange_314_0.jpg
# Objet détecté enregistré : detected_objects\banana_314_1.jpg
# Objet détecté enregistré : detected_objects\orange_314_2.jpg
# Objet détecté enregistré : detected_objects\banana_314_3.jpg
#
# 0: 608x640 1 bowl, 1 banana, 1 apple, 6 oranges, 124.5ms
# Speed: 4.7ms preprocess, 124.5ms inference, 1.4ms postprocess per image at shape (1, 3, 608, 640)
# Objet détecté enregistré : detected_objects\apple_316_0.jpg
# Objet détecté enregistré : detected_objects\banana_316_1.jpg
# Objet détecté enregistré : detected_objects\orange_316_2.jpg
# Objet détecté enregistré : detected_objects\orange_316_3.jpg
# Objet détecté enregistré : detected_objects\orange_316_4.jpg
# Objet détecté enregistré : detected_objects\orange_316_5.jpg
# Objet détecté enregistré : detected_objects\orange_316_7.jpg
# Objet détecté enregistré : detected_objects\orange_316_8.jpg
#
# 0: 480x640 1 banana, 2 apples, 1 orange, 134.6ms
# Speed: 3.1ms preprocess, 134.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_318_0.jpg
# Objet détecté enregistré : detected_objects\apple_318_1.jpg
# Objet détecté enregistré : detected_objects\banana_318_2.jpg
# Objet détecté enregistré : detected_objects\apple_318_3.jpg
#
# 0: 576x640 1 orange, 98.7ms
# Speed: 4.0ms preprocess, 98.7ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# Objet détecté enregistré : detected_objects\orange_320_0.jpg
#
# 0: 544x640 1 banana, 2 apples, 1 orange, 137.0ms
# Speed: 2.9ms preprocess, 137.0ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
# Objet détecté enregistré : detected_objects\apple_322_0.jpg
# Objet détecté enregistré : detected_objects\apple_322_1.jpg
# Objet détecté enregistré : detected_objects\orange_322_2.jpg
# Objet détecté enregistré : detected_objects\banana_322_3.jpg
#
# 0: 640x480 1 banana, 1 apple, 1 orange, 105.2ms
# Speed: 2.6ms preprocess, 105.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Objet détecté enregistré : detected_objects\apple_324_0.jpg
# Objet détecté enregistré : detected_objects\orange_324_1.jpg
# Objet détecté enregistré : detected_objects\banana_324_2.jpg
#
# 0: 640x640 1 banana, 1 apple, 1 orange, 150.4ms
# Speed: 4.4ms preprocess, 150.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_326_0.jpg
# Objet détecté enregistré : detected_objects\apple_326_1.jpg
# Objet détecté enregistré : detected_objects\banana_326_2.jpg
#
# 0: 448x640 1 banana, 1 apple, 2 oranges, 108.0ms
# Speed: 1.7ms preprocess, 108.0ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\orange_328_0.jpg
# Objet détecté enregistré : detected_objects\banana_328_1.jpg
# Objet détecté enregistré : detected_objects\orange_328_2.jpg
# Objet détecté enregistré : detected_objects\apple_328_3.jpg
#
# 0: 416x640 1 banana, 2 apples, 1 orange, 94.2ms
# Speed: 1.8ms preprocess, 94.2ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
# Objet détecté enregistré : detected_objects\orange_330_0.jpg
# Objet détecté enregistré : detected_objects\apple_330_1.jpg
# Objet détecté enregistré : detected_objects\apple_330_2.jpg
# Objet détecté enregistré : detected_objects\banana_330_3.jpg
#
# 0: 608x640 1 banana, 1 apple, 1 orange, 132.4ms
# Speed: 4.5ms preprocess, 132.4ms inference, 0.9ms postprocess per image at shape (1, 3, 608, 640)
# Objet détecté enregistré : detected_objects\banana_332_0.jpg
# Objet détecté enregistré : detected_objects\orange_332_1.jpg
# Objet détecté enregistré : detected_objects\apple_332_2.jpg
#
# 0: 640x640 3 umbrellas, 1 kite, 148.9ms
# Speed: 3.4ms preprocess, 148.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 10 oranges, 95.1ms
# Speed: 1.1ms preprocess, 95.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
# Objet détecté enregistré : detected_objects\orange_336_0.jpg
# Objet détecté enregistré : detected_objects\orange_336_1.jpg
# Objet détecté enregistré : detected_objects\orange_336_2.jpg
# Objet détecté enregistré : detected_objects\orange_336_3.jpg
# Objet détecté enregistré : detected_objects\orange_336_4.jpg
# Objet détecté enregistré : detected_objects\orange_336_5.jpg
# Objet détecté enregistré : detected_objects\orange_336_6.jpg
# Objet détecté enregistré : detected_objects\orange_336_7.jpg
# Objet détecté enregistré : detected_objects\orange_336_8.jpg
# Objet détecté enregistré : detected_objects\orange_336_9.jpg
#
# 0: 384x640 3 oranges, 87.7ms
# Speed: 1.4ms preprocess, 87.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\orange_338_0.jpg
# ...
# Objet détecté enregistré : detected_objects\orange_374_2.jpg
# Objet détecté enregistré : detected_objects\orange_374_3.jpg
#
# 0: 640x640 1 orange, 135.7ms
# Speed: 3.9ms preprocess, 135.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_376_0.jpg
#
# 0: 448x640 4 oranges, 1 dining table, 100.6ms
# Speed: 1.8ms preprocess, 100.6ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\orange_378_0.jpg
# Objet détecté enregistré : detected_objects\orange_378_1.jpg
# Objet détecté enregistré : detected_objects\orange_378_2.jpg
# Objet détecté enregistré : detected_objects\orange_378_4.jpg
#
# 0: 640x640 10 oranges, 134.6ms
# Speed: 3.5ms preprocess, 134.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_380_0.jpg
# Objet détecté enregistré : detected_objects\orange_380_1.jpg
# Objet détecté enregistré : detected_objects\orange_380_2.jpg
# Objet détecté enregistré : detected_objects\orange_380_3.jpg
# Objet détecté enregistré : detected_objects\orange_380_4.jpg
# Objet détecté enregistré : detected_objects\orange_380_5.jpg
# Objet détecté enregistré : detected_objects\orange_380_6.jpg
# Objet détecté enregistré : detected_objects\orange_380_7.jpg
# Objet détecté enregistré : detected_objects\orange_380_8.jpg
# Objet détecté enregistré : detected_objects\orange_380_9.jpg
#
# 0: 640x640 1 orange, 125.7ms
# Speed: 4.9ms preprocess, 125.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_382_0.jpg
#
# 0: 608x640 4 oranges, 130.6ms
# Speed: 4.4ms preprocess, 130.6ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
# Objet détecté enregistré : detected_objects\orange_384_0.jpg
# Objet détecté enregistré : detected_objects\orange_384_1.jpg
# Objet détecté enregistré : detected_objects\orange_384_2.jpg
# Objet détecté enregistré : detected_objects\orange_384_3.jpg
#
# 0: 480x640 3 oranges, 111.7ms
# Speed: 2.0ms preprocess, 111.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_386_0.jpg
# Objet détecté enregistré : detected_objects\orange_386_1.jpg
# Objet détecté enregistré : detected_objects\orange_386_2.jpg
#
# 0: 384x640 1 umbrella, 1 orange, 97.0ms
# Speed: 1.6ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Objet détecté enregistré : detected_objects\orange_388_0.jpg
#
# 0: 480x640 2 oranges, 119.7ms
# Speed: 4.8ms preprocess, 119.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_390_0.jpg
# Objet détecté enregistré : detected_objects\orange_390_1.jpg
#
# 0: 640x640 (no detections), 138.9ms
# Speed: 3.9ms preprocess, 138.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 6 oranges, 92.9ms
# Speed: 2.7ms preprocess, 92.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_394_0.jpg
# Objet détecté enregistré : detected_objects\orange_394_1.jpg
# Objet détecté enregistré : detected_objects\orange_394_2.jpg
# Objet détecté enregistré : detected_objects\orange_394_3.jpg
# Objet détecté enregistré : detected_objects\orange_394_4.jpg
# Objet détecté enregistré : detected_objects\orange_394_5.jpg
#
# 0: 544x640 1 apple, 1 orange, 120.2ms
# Speed: 2.9ms preprocess, 120.2ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
# Objet détecté enregistré : detected_objects\orange_396_0.jpg
# Objet détecté enregistré : detected_objects\apple_396_1.jpg
#
# 0: 640x640 5 oranges, 108.9ms
# Speed: 5.0ms preprocess, 108.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_398_0.jpg
# Objet détecté enregistré : detected_objects\orange_398_1.jpg
# Objet détecté enregistré : detected_objects\orange_398_2.jpg
# Objet détecté enregistré : detected_objects\orange_398_3.jpg
# Objet détecté enregistré : detected_objects\orange_398_4.jpg
#
# 0: 640x640 1 orange, 141.1ms
# Speed: 4.7ms preprocess, 141.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_400_0.jpg
#
# 0: 480x640 3 oranges, 103.5ms
# Speed: 2.1ms preprocess, 103.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_402_0.jpg
# Objet détecté enregistré : detected_objects\orange_402_1.jpg
# Objet détecté enregistré : detected_objects\orange_402_2.jpg
#
# 0: 416x640 4 oranges, 88.1ms
# Speed: 1.8ms preprocess, 88.1ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
# Objet détecté enregistré : detected_objects\orange_404_0.jpg
# Objet détecté enregistré : detected_objects\orange_404_1.jpg
# Objet détecté enregistré : detected_objects\orange_404_2.jpg
# Objet détecté enregistré : detected_objects\orange_404_3.jpg
#
# 0: 640x640 (no detections), 119.6ms
# Speed: 4.5ms preprocess, 119.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 oranges, 120.8ms
# Speed: 4.2ms preprocess, 120.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_408_0.jpg
# Objet détecté enregistré : detected_objects\orange_408_1.jpg
# Objet détecté enregistré : detected_objects\orange_408_2.jpg
#
# 0: 480x640 1 orange, 97.5ms
# Speed: 2.6ms preprocess, 97.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_410_0.jpg
#
# 0: 608x640 1 orange, 114.2ms
# Speed: 5.0ms preprocess, 114.2ms inference, 1.4ms postprocess per image at shape (1, 3, 608, 640)
# Objet détecté enregistré : detected_objects\orange_412_0.jpg
#
# 0: 544x640 2 oranges, 121.1ms
# Speed: 3.4ms preprocess, 121.1ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
# Objet détecté enregistré : detected_objects\orange_414_0.jpg
# Objet détecté enregistré : detected_objects\orange_414_1.jpg
#
# 0: 480x640 3 oranges, 123.5ms
# Speed: 1.7ms preprocess, 123.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_416_0.jpg
# Objet détecté enregistré : detected_objects\orange_416_1.jpg
# Objet détecté enregistré : detected_objects\orange_416_2.jpg
#
# 0: 640x608 1 umbrella, 1 kite, 2 oranges, 167.6ms
# Speed: 4.3ms preprocess, 167.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
# Objet détecté enregistré : detected_objects\orange_418_0.jpg
# Objet détecté enregistré : detected_objects\orange_418_1.jpg
#
# 0: 512x640 1 apple, 2 oranges, 99.0ms
# Speed: 2.7ms preprocess, 99.0ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
# Objet détecté enregistré : detected_objects\orange_420_0.jpg
# Objet détecté enregistré : detected_objects\apple_420_1.jpg
# Objet détecté enregistré : detected_objects\orange_420_2.jpg
#
# 0: 480x640 3 oranges, 98.5ms
# Speed: 2.0ms preprocess, 98.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_422_0.jpg
# Objet détecté enregistré : detected_objects\orange_422_1.jpg
# Objet détecté enregistré : detected_objects\orange_422_2.jpg
#
# 0: 448x640 3 oranges, 101.4ms
# Speed: 2.0ms preprocess, 101.4ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\orange_424_0.jpg
# Objet détecté enregistré : detected_objects\orange_424_1.jpg
# Objet détecté enregistré : detected_objects\orange_424_2.jpg
#
# 0: 640x640 2 oranges, 134.2ms
# Speed: 3.8ms preprocess, 134.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_426_0.jpg
# Objet détecté enregistré : detected_objects\orange_426_1.jpg
#
# 0: 608x640 1 orange, 131.5ms
# Speed: 4.6ms preprocess, 131.5ms inference, 0.9ms postprocess per image at shape (1, 3, 608, 640)
# Objet détecté enregistré : detected_objects\orange_428_0.jpg
#
# 0: 640x640 5 oranges, 136.2ms
# Speed: 3.9ms preprocess, 136.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_430_0.jpg
# Objet détecté enregistré : detected_objects\orange_430_1.jpg
# Objet détecté enregistré : detected_objects\orange_430_2.jpg
# Objet détecté enregistré : detected_objects\orange_430_3.jpg
# Objet détecté enregistré : detected_objects\orange_430_4.jpg
#
# 0: 480x640 1 orange, 112.3ms
# Speed: 2.1ms preprocess, 112.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_432_0.jpg
#
# 0: 544x640 5 oranges, 135.8ms
# Speed: 3.9ms preprocess, 135.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# Objet détecté enregistré : detected_objects\orange_434_0.jpg
# Objet détecté enregistré : detected_objects\orange_434_1.jpg
# Objet détecté enregistré : detected_objects\orange_434_2.jpg
# Objet détecté enregistré : detected_objects\orange_434_3.jpg
# Objet détecté enregistré : detected_objects\orange_434_4.jpg
#
# 0: 640x480 6 oranges, 108.0ms
# Speed: 2.9ms preprocess, 108.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Objet détecté enregistré : detected_objects\orange_436_0.jpg
# Objet détecté enregistré : detected_objects\orange_436_1.jpg
# Objet détecté enregistré : detected_objects\orange_436_2.jpg
# Objet détecté enregistré : detected_objects\orange_436_3.jpg
# Objet détecté enregistré : detected_objects\orange_436_4.jpg
# Objet détecté enregistré : detected_objects\orange_436_5.jpg
#
# 0: 352x640 3 oranges, 84.9ms
# Speed: 1.5ms preprocess, 84.9ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# Objet détecté enregistré : detected_objects\orange_438_0.jpg
# Objet détecté enregistré : detected_objects\orange_438_1.jpg
# Objet détecté enregistré : detected_objects\orange_438_2.jpg
#
# 0: 640x640 3 oranges, 135.8ms
# Speed: 3.4ms preprocess, 135.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_440_0.jpg
# Objet détecté enregistré : detected_objects\orange_440_1.jpg
# Objet détecté enregistré : detected_objects\orange_440_2.jpg
#
# 0: 480x640 1 orange, 116.3ms
# Speed: 1.5ms preprocess, 116.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_442_0.jpg
#
# 0: 640x608 (no detections), 137.1ms
# Speed: 6.8ms preprocess, 137.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x640 4 oranges, 160.1ms
# Speed: 6.6ms preprocess, 160.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_446_0.jpg
# Objet détecté enregistré : detected_objects\orange_446_1.jpg
# Objet détecté enregistré : detected_objects\orange_446_2.jpg
# Objet détecté enregistré : detected_objects\orange_446_3.jpg
#
# 0: 352x640 5 oranges, 96.5ms
# Speed: 2.1ms preprocess, 96.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# Objet détecté enregistré : detected_objects\orange_448_0.jpg
# Objet détecté enregistré : detected_objects\orange_448_1.jpg
# Objet détecté enregistré : detected_objects\orange_448_2.jpg
# Objet détecté enregistré : detected_objects\orange_448_3.jpg
# Objet détecté enregistré : detected_objects\orange_448_4.jpg
#
# 0: 448x640 2 oranges, 98.6ms
# Speed: 2.4ms preprocess, 98.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\orange_450_0.jpg
# Objet détecté enregistré : detected_objects\orange_450_1.jpg
#
# 0: 640x640 2 oranges, 127.7ms
# Speed: 4.8ms preprocess, 127.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_452_0.jpg
# Objet détecté enregistré : detected_objects\orange_452_1.jpg
#
# 0: 352x640 2 oranges, 86.4ms
# Speed: 1.5ms preprocess, 86.4ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# Objet détecté enregistré : detected_objects\orange_454_0.jpg
# Objet détecté enregistré : detected_objects\orange_454_1.jpg
#
# 0: 512x640 1 orange, 110.1ms
# Speed: 2.1ms preprocess, 110.1ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
# Objet détecté enregistré : detected_objects\orange_456_0.jpg
#
# 0: 416x640 1 wine glass, 6 oranges, 102.9ms
# Speed: 1.9ms preprocess, 102.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# Objet détecté enregistré : detected_objects\orange_458_0.jpg
# Objet détecté enregistré : detected_objects\orange_458_2.jpg
# Objet détecté enregistré : detected_objects\orange_458_3.jpg
# Objet détecté enregistré : detected_objects\orange_458_4.jpg
# Objet détecté enregistré : detected_objects\orange_458_5.jpg
# Objet détecté enregistré : detected_objects\orange_458_6.jpg
#
# 0: 352x640 2 oranges, 91.4ms
# Speed: 3.6ms preprocess, 91.4ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# Objet détecté enregistré : detected_objects\orange_460_0.jpg
# Objet détecté enregistré : detected_objects\orange_460_1.jpg
#
# 0: 480x640 4 oranges, 113.8ms
# Speed: 2.1ms preprocess, 113.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_462_0.jpg
# Objet détecté enregistré : detected_objects\orange_462_1.jpg
# Objet détecté enregistré : detected_objects\orange_462_2.jpg
# Objet détecté enregistré : detected_objects\orange_462_3.jpg
#
# 0: 576x640 1 orange, 130.7ms
# Speed: 3.8ms preprocess, 130.7ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# Objet détecté enregistré : detected_objects\orange_464_0.jpg
#
# 0: 640x640 1 orange, 133.5ms
# Speed: 3.6ms preprocess, 133.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_466_0.jpg
#
# 0: 480x640 1 orange, 115.5ms
# Speed: 2.0ms preprocess, 115.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Objet détecté enregistré : detected_objects\orange_468_0.jpg
#
# 0: 512x640 4 oranges, 116.2ms
# Speed: 3.2ms preprocess, 116.2ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
# Objet détecté enregistré : detected_objects\orange_470_0.jpg
# Objet détecté enregistré : detected_objects\orange_470_1.jpg
# Objet détecté enregistré : detected_objects\orange_470_2.jpg
# Objet détecté enregistré : detected_objects\orange_470_3.jpg
#
# 0: 640x640 1 orange, 131.7ms
# Speed: 5.2ms preprocess, 131.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Objet détecté enregistré : detected_objects\orange_472_0.jpg
#
# 0: 448x640 10 oranges, 110.3ms
# Speed: 2.4ms preprocess, 110.3ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\orange_474_0.jpg
# Objet détecté enregistré : detected_objects\orange_474_1.jpg
# Objet détecté enregistré : detected_objects\orange_474_2.jpg
# Objet détecté enregistré : detected_objects\orange_474_3.jpg
# Objet détecté enregistré : detected_objects\orange_474_4.jpg
# Objet détecté enregistré : detected_objects\orange_474_5.jpg
# Objet détecté enregistré : detected_objects\orange_474_6.jpg
# Objet détecté enregistré : detected_objects\orange_474_7.jpg
# Objet détecté enregistré : detected_objects\orange_474_8.jpg
# Objet détecté enregistré : detected_objects\orange_474_9.jpg
#
# 0: 448x640 4 oranges, 100.1ms
# Speed: 3.1ms preprocess, 100.1ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# Objet détecté enregistré : detected_objects\orange_476_0.jpg
# Objet détecté enregistré : detected_objects\orange_476_1.jpg
# Objet détecté enregistré : detected_objects\orange_476_2.jpg
# Objet détecté enregistré : detected_objects\orange_476_3.jpg
#
# 0: 576x640 3 oranges, 134.4ms
# Speed: 5.1ms preprocess, 134.4ms inference, 0.9ms postprocess per image at shape (1, 3, 576, 640)
# Objet détecté enregistré : detected_objects\orange_478_0.jpg
# Objet détecté enregistré : detected_objects\orange_478_1.jpg
# Objet détecté enregistré : detected_objects\orange_478_2.jpg
# Extraction terminée.

# %%
# Dossier contenant les images extraites par YOLO
dossier = "detected_objects"

# Initialisation d'un tableau pour stocker les descripteurs
tab_descripteurs = []

# Parcourir toutes les images du dossier
for nom_fichier in os.listdir(dossier):
    if nom_fichier.endswith(".jpg"): 
        # Charger l'image
        chemin_image = os.path.join(dossier, nom_fichier)
        image = cv2.imread(chemin_image)

        if image is None:
            print(f"Erreur : Impossible de charger {chemin_image}")
            continue  # Passe à l'image suivante

        # Extraire les descripteurs
        color_features = extract_color_histogram(image)
        shape_features = extract_shape_features(image)
        hog_features = extract_hog_features(image)

        # Vérifier que les descripteurs existent
        if shape_features is None or len(shape_features) == 0:
            shape_features = np.array([0])  # Valeur par défaut si aucun contour

        # Concaténer les descripteurs en un seul vecteur
        feature_vector = np.concatenate([color_features, shape_features, hog_features])

        # Ajouter le vecteur au tableau des descripteurs
        tab_descripteurs.append(feature_vector)


# Convertir la liste en un tableau NumPy final
if tab_descripteurs:
    tab_descripteurs = np.vstack(tab_descripteurs)
else:
    tab_descripteurs = np.array([])  # Tableau vide si aucune image n'a été traitée
    print(" Aucun descripteur n'a été extrait.")

# %% [markdown]
# test avec un mlp

# %%
X = tab_descripteurs  # Ton tableau numpy (features)

labels = [nom.split("_")[0] for nom in os.listdir("detected_objects") if nom.endswith(".jpg")]
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)
y = encoded_labels  # Une liste ou array numpy des classes associées

# Normaliser les données (important pour MLP)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Séparer en train/test (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=1)

# Définir le modèle MLP
mlp = MLPClassifier(hidden_layer_sizes=(30, 10), activation='relu', max_iter=500)

# Entraîner le modèle
mlp.fit(X_train, y_train)

# Prédire sur le test set
y_pred = mlp.predict(X_test)

# Évaluer la précision
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
print(f"Accuracy du modèle : {accuracy:.2f}")
print(f"Précision du modèle : {precision:.2f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 13
#      10 X_scaled = scaler.fit_transform(X)
#      12 # Séparer en train/test (70% train, 30% test)
# ---> 13 X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=1)
#      15 # Définir le modèle MLP
#      16 mlp = MLPClassifier(hidden_layer_sizes=(30, 10), activation='relu', max_iter=500)
#
# File c:\Users\StéphanieAGBANGLANON\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\StéphanieAGBANGLANON\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:2777, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2774 if n_arrays == 0:
#    2775     raise ValueError("At least one array required as input")
# -> 2777 arrays = indexable(*arrays)
#    2779 n_samples = _num_samples(arrays[0])
#    2780 n_train, n_test = _validate_shuffle_split(
#    2781     n_samples, test_size, train_size, default_test_size=0.25
#    2782 )
#
# File c:\Users\StéphanieAGBANGLANON\anaconda3\Lib\site-packages\sklearn\utils\validation.py:514, in indexable(*iterables)
#     484 """Make arrays indexable for cross-validation.
#     485
#     486 Checks consistent length, passes through None, and ensures that everything
#    (...)
#     510 [[1, 2, 3], array([2, 3, 4]), None, <3x1 sparse matrix ...>]
#     511 """
#     513 result = [_make_indexable(X) for X in iterables]
# --> 514 check_consistent_length(*result)
#     515 return result
#
# File c:\Users\StéphanieAGBANGLANON\anaconda3\Lib\site-packages\sklearn\utils\validation.py:457, in check_consistent_length(*arrays)
#     455 uniques = np.unique(lengths)
#     456 if len(uniques) > 1:
# --> 457     raise ValueError(
#     458         "Found input variables with inconsistent numbers of samples: %r"
#     459         % [int(l) for l in lengths]
#     460     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [240, 643]
